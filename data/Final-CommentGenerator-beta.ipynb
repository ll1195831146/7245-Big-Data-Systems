# %% [markdown]
# # Code Comments Generator using RNN

# %% [markdown]
# Code comments are often as important as codes in a program, especially when the projects are done by a team.
# * It's important to communicate what the code SHOULD be doing
# * Comments show respect for the next developer to read your code
# * Comments indicate potential problem areas to avoid

# %% [markdown]
# # Evaluation Index

# %% [markdown]
# **MSE for RNN model**
#
# **BLEU-4 for Comments**
#
# BLEU, or the Bilingual Evaluation Understudy, is a score for comparing a candidate translation of text to one or more reference translations.
# BLEU is essentially to calculate the frequency of co-occurrence words in two sentences.

# %% [markdown]
# ## RNN(Recurrent Neural Network)

# %% [markdown]
# A recurrent neural network (RNN) is a class of artificial neural network where connections between units form a directed graph along a sequence. This allows it to exhibit dynamic temporal behavior for a time sequence.
#
# Basic RNNs are a network of neuron-like nodes organized into successive "layers", each node in a given layer is connected with a directed (one-way) connection to every other node in the next successive layer. Each node (neuron) has a time-varying real-valued activation. Each connection (synapse) has a modifiable real-valued weight. Nodes are either input nodes (receiving data from outside the network), output nodes (yielding results), or hidden nodes (that modify the data en route from input to output).
#
# from __[Recurrent neural network - Wikipedia)](https://en.wikipedia.org/wiki/Recurrent_neural_network)__

# %% [markdown]
# ![RNN](data/RNN.png)

# %% [markdown]
# ## Introduction to Tensorflow

# %% [markdown]
# TensorFlow is a  leading deep learning and neural network computation framework. It is based on a C++ low level backend but is usually controlled via Python.
#
# Tensorflow has a multi-hierarchy structure, which can be deployed in various servers, PC terminals and web pages, and supports high-performance numerical computation of GPU and TPU. Tensorflow is widely used in Google internal product development and scientific research in various fields.

# %% [markdown]
# ## Learning strategies

# %% [markdown]
# First, covert the raw data( training and testing) to a sequence of vectors with 50 digits during preprocessing. After encoding the input sequence to a vector , feed the encoded data to RNN model and get predicting sequences. Finally decode the output sequence of vectors and the results are expected comments.

# %% [markdown]
# ![workflow](data/workflow.png)

# %% [markdown]
# We will read the text file, then split the content into an array which each element is a word, and store it into data variable. Next, we will create a new array called characterlist to store the unique values for training and testing data separately.

# %% [markdown]
# ![vectorization](data/vectorization.png)

# %% [markdown]
# ## Prepare the dataset
#
# Our dataset was collected from [UCI](https://www.ics.uci.edu/~lopes/datasets/). The dataset contains 470486 minutes of data.

# %%
# %matplotlib inline
from collections import Counter
import random

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Read raw data
rawdata=pd.read_json('data/train.json',lines=True)

# %%
# Show format of dataset
rawdata
# Out:
#                                                      code  \
# 0                         protected void tearDown(){\n}\n
# 1       @KnownFailure("Fixed on DonutBurger, Wrong Exc...
# 2       public static CstFloat make(int bits){\n  retu...
# 3       public long size(){\n  long size=0;\n  if (par...
# 4       public void increment(View view){\n  if (quant...
# 5       public void trimToSize(){\n  ++modCount;\n  if...
# 6       public SyncValueResponseMessage(SyncValueRespo...
# 7       public void clearParsers(){\n  if (parserManag...
# 8       @Override public void run(){\n  while (doWork)...
# 9       private byte[] calculateUValue(byte[] generalK...
# 10      private void assign(HashMap<String,DBIDs> labe...
# 11      private void showFeedback(String message){\n  ...
# 12      public CDeleteAction(final BackEndDebuggerProv...
# 13      public Yaml(BaseConstructor constructor,Repres...
# 14      public void testHitEndAfterFind(){\n  hitEndTe...
# 15      public void add(Individual individual){\n  ind...
# 16      public boolean removeSession(IgniteUuid sesId)...
# 17      public static Bitmap loadBitmapOptimized(Uri u...
# 18      protected BasePeriod(long duration){\n  super(...
# 19        public FlatBufferBuilder(){\n  this(1024);\n}\n
# 20      public PbrpcConnectionException(String arg0,Th...
# 21      public void uninstallUI(JComponent a){\n  for ...
# 22      public static void shutdown(){\n  if (instance...
# 23      public boolean GE(Word w2){\n  return value.GE...
# 24      public static UnionCoder of(List<Coder<?>> ele...
# 25      public void testFileDeletion() throws Exceptio...
# 26      public boolean isOnClasspath(String classpath)...
# 27      protected void source(String ceylon){\n  Strin...
# 28      public PerformanceMonitor(){\n  initComponents...
# 29      @DSGenerator(tool_name="Doppelganger",tool_ver...
# ...                                                   ...
# 470456  int[] decodeStart(BitArray row) throws NotFoun...
# 470457  public static boolean contains(int[] array,int...
# 470458  public static double acosh(final double value)...
# 470459  public void fireDataStatusEEvent(String AD_Mes...
# 470460  AttributeDefinition(TextAttributeSet attrs,int...
# 470461  public void consumeGreedy(String greedyToken){...
# 470462  public static int hexToDecimal(String hex) thr...
# 470463  @Override public Result decode(BinaryBitmap im...
# 470464  public BackupFileSet listRawBackup(final boole...
# 470465  public CountingIdlingResource(String resourceN...
# 470466  public ImageReuseInfo create(String thisSize){...
# 470467  public static void sync(Address address,int si...
# 470468  public MonthDateFormat(Locale locale){\n  this...
# 470469  public void testConnectorSecuritySettingsSSL_a...
# 470470  public synchronized void add(double x,double y...
# 470471  public void fatalError(SAXParseException excep...
# 470472  @Override public void run(){\n  amIActive=true...
# 470473  public static void addMoreComponents(Container...
# 470474  public static CCProgressTimer progress(CCTextu...
# 470475  protected EntityMappingModelImpl(){\n  super()...
# 470476  public MatchResult match(){\n  if (!matchSucce...
# 470477  @Override public void dispatch(IEvent event){\...
# 470478  JComboBox createMouthComboBox(){\n  JComboBox ...
# 470479  public double leverageForRule(AprioriItemSet p...
# 470480  public RdKNNNode(int capacity,boolean isLeaf){...
# 470481  private void adaptGridViewHeight(){\n  if (gri...
# 470482  protected void validateOnStatus(){\n  if (Comm...
# 470483  public Optional<Boolean> eagerCheck(){\n  retu...
# 470484  public static NewPlaylistFragment newInstance(...
# 470485  @DSSink({DSSinkKind.LOG}) @DSGenerator(tool_na...
#
#                                                        nl
# 0       Tears down the fixture, for example, close a n...
# 1       javax.net.ssl.SSLEngine#unwrap(ByteBuffer src,...
# 2       Makes an instance for the given value. This ma...
# 3       Returns the "size" of the chromosome, namely, ...
# 4       This method is called when the plus button is ...
# 5       Trims the capacity of this <tt>ArrayHashList</...
# 6                   Performs a deep copy on <i>other</i>.
# 7                Removes all parsers from this text area.
# 8       This is the code for the thread. It delivers d...
# 9       Calculate what the U value should consist of g...
# 10      Assigns the specified id to the labelMap accor...
# 11      Used to communicate feedback pop-up messages b...
# 12                           Creates a new action object.
# 13      Create Yaml instance. It is safe to create a f...
# 14                       Regression test for HARMONY-4396
# 15                              Adds a single individual.
# 16                Removes session for a given session ID.
# 17      Loading bitmap with optimized loaded size less...
# 18      Creates a period from the given millisecond du...
# 19      Start with a buffer of 1KiB, then grow as requ...
# 20      Creates a new instance of PbrpcConnectionExcep...
# 21      Invokes the <code>uninstallUI</code> method on...
# 22                          Saves the configuration file.
# 23                       Greater-than or equal comparison
# 24      Builds a union coder with the given list of el...
# 25              Verify ability to delete a list of files.
# 26      Evaluates if the Dependency is targeted for a ...
# 27      Checks that we can still compile a client afte...
# 28                    Creates new form PerformanceMonitor
# 29              Wakes up node's successor, if one exists.
# ...                                                   ...
# 470456  Identify where the start of the middle / paylo...
# 470457  Returns <code>true</code> if an array contains...
# 470458  Some properties of acosh(x) = log(x + sqrt(x^2...
# 470459            Create and fire Data Status Error Event
# 470460                    Create new AttributeDefinition.
# 470461  Consumes a substring from the current sval of ...
# 470462  Converts a hex string into a decimal number an...
# 470463         Locates and decodes a QR code in an image.
# 470464                     Get a list of backup sets info
# 470465                  Creates a CountingIdlingResource.
# 470466             Find out the size list can be re-sued.
# 470467  Synchronize a region of memory: force data in ...
# 470468  Creates a new instance for the specified time ...
# 470469  Confirm behavior when connector.security.use.S...
# 470470                    Adds a new value to the series.
# 470471  This method is called when a fatal error occur...
# 470472                  Used to execute this plugin tool.
# 470473  Invoke this method to add additional component...
# 470474  Creates a progress timer with the texture as t...
# 470475      <!-- begin-user-doc --> <!-- end-user-doc -->
# 470476  Returns the result of the last matching operat...
# 470477  Sends an IEvent to all listeners that listen f...
# 470478                       Creates the mouth combo box.
# 470479  Outputs the leverage for a rule. Leverage is d...
# 470480                    Creates a new RdKNNNode object.
# 470481  Adapts the height of the grid view, which is u...
# 470482  Validates the arguments passed to the Builder ...
# 470483           whether check errors as more as possible
# 470484  Creates a new instance of the New Playlist dia...
# 470485  Report the current cursor location in its window.
#
# [470486 rows x 2 columns]

# %%
# Make data a np.array
rawdata.dropna()
rawdata = rawdata.values

# %%
# Build X and y
X = rawdata[:, 0]
y = rawdata[:, 1:]

# %%
X
# Out:
# array(['protected void tearDown(){\n}\n',
#        '@KnownFailure("Fixed on DonutBurger, Wrong Exception thrown") public void test_unwrap_ByteBuffer$ByteBuffer_02(){\n  String host="new host";\n  int port=8080;\n  ByteBuffer bbs=ByteBuffer.allocate(10);\n  ByteBuffer bbR=ByteBuffer.allocate(100).asReadOnlyBuffer();\n  ByteBuffer[] bbA={bbR,ByteBuffer.allocate(10),ByteBuffer.allocate(100)};\n  SSLEngine sse=getEngine(host,port);\n  sse.setUseClientMode(true);\n  try {\n    sse.unwrap(bbs,bbA);\n    fail("ReadOnlyBufferException wasn\'t thrown");\n  }\n catch (  ReadOnlyBufferException iobe) {\n  }\ncatch (  Exception e) {\n    fail(e + " was thrown instead of ReadOnlyBufferException");\n  }\n}\n',
#        'public static CstFloat make(int bits){\n  return new CstFloat(bits);\n}\n',
#        ...,
#        'public Optional<Boolean> eagerCheck(){\n  return Optional.ofNullable(this.eagerCheck);\n}\n',
#        'public static NewPlaylistFragment newInstance(Song song){\n  NewPlaylistFragment fragment=new NewPlaylistFragment();\n  Bundle bundle=new Bundle();\n  bundle.putParcelable(KEY_SONG,song);\n  fragment.setArguments(bundle);\n  return fragment;\n}\n',
#        '@DSSink({DSSinkKind.LOG}) @DSGenerator(tool_name="Doppelganger",tool_version="2.0",generated_on="2013-12-30 12:29:19.771 -0500",hash_original_method="06AF2B97EC9C8BBE1303A237FE727449",hash_generated_method="103A7E1B02C228D1981B721CBC7DAC4C") public void updateCursor(View view,int left,int top,int right,int bottom){\n  checkFocus();\nsynchronized (mH) {\n    if ((mServedView != view && (mServedView == null || !mServedView.checkInputConnectionProxy(view))) || mCurrentTextBoxAttribute == null || mCurMethod == null) {\n      return;\n    }\n    mTmpCursorRect.set(left,top,right,bottom);\n    if (!mCursorRect.equals(mTmpCursorRect)) {\n      if (DEBUG)       Log.d(TAG,"updateCursor");\n      try {\n        if (DEBUG)         Log.v(TAG,"CURSOR CHANGE: " + mCurMethod);\n        mCurMethod.updateCursor(mTmpCursorRect);\n        mCursorRect.set(mTmpCursorRect);\n      }\n catch (      RemoteException e) {\n        Log.w(TAG,"IME died: " + mCurId,e);\n      }\n    }\n  }\n}\n'], dtype=object)

# %%
y
# Out:
# array([[ 'Tears down the fixture, for example, close a network connection. This method is called after a test is executed.'],
#        [ 'javax.net.ssl.SSLEngine#unwrap(ByteBuffer src, ByteBuffer[] dsts) ReadOnlyBufferException should be thrown.'],
#        [ 'Makes an instance for the given value. This may (but does not necessarily) return an already-allocated instance.'],
#        ...,
#        ['whether check errors as more as possible'],
#        [ 'Creates a new instance of the New Playlist dialog fragment to create a new playlist and add a song to it.'],
#        ['Report the current cursor location in its window.']], dtype=object)

# %% [markdown]
# ## Tokenization & Generating Vocabulary

# %% [markdown]
# We tokenized features data and label data to two vocabulary separately, because the format of java codes and human words are quite different.

# %%
from collections import Counter
import time
from itertools import chain
from nltk import sent_tokenize, word_tokenize
from nltk.tokenize import ToktokTokenizer
toktok = ToktokTokenizer()

# %% [markdown]
# ### Get Features Vocabulary

# %%
# %%time
start=time.time()
Chracterlist_code = []
i = 0
for s in X:
    i = i+1
    Chracterlist_code.extend(toktok.tokenize(s))
    if i % 100000 == 0:
        print('----------------------------------------')
        print('Pieces of data: %s'%(i))
        print('The length of List: %s'%(len(Chracterlist_code)))
        end=time.time()
        print('Running time: %s Seconds'%(end-start))
# Out:
# ----------------------------------------
# Pieces of data: 100000
# The length of List: 7152616
# Running time: 32.0409209728241 Seconds
# ----------------------------------------
# Pieces of data: 200000
# The length of List: 14354948
# Running time: 63.855900049209595 Seconds
# ----------------------------------------
# Pieces of data: 300000
# The length of List: 21568075
# Running time: 91.99899792671204 Seconds
# ----------------------------------------
# Pieces of data: 400000
# The length of List: 28778707
# Running time: 121.17291712760925 Seconds
# CPU times: user 2min 18s, sys: 2.9 s, total: 2min 21s
# Wall time: 2min 24s

# %%
#Vocabulary for vectorization and  use Vectorized data to fit model
vocabs_code = sorted(list(set(Chracterlist_code)))
code_to_int = dict((c, i) for i, c in enumerate(vocabs_code))   #Vectorize the text
int_to_code = dict((i, c) for i, c in enumerate(vocabs_code))
data_vocabs_code=pd.DataFrame(data=vocabs_code)#
data_vocabs_code.to_csv('vocabs_code.csv',encoding='gbk')

# %% [markdown]
# ### Get Labels Vocabulary

# %%
# %%time
start=time.time()
Chracterlist_comment = []
i = 0
for s in y[:,0]:
    i = i+1
    Chracterlist_comment.extend(toktok.tokenize(s))
    if i % 100000 == 0:
        print('----------------------------------------')
        print('Pieces of data: %s'%(i))
        print('The length of List: %s'%(len(Chracterlist_comment)))
        end=time.time()
        print('Running time: %s Seconds'%(end-start))
# Out:
# ----------------------------------------
# Pieces of data: 100000
# The length of List: 1652981
# Running time: 8.005395889282227 Seconds
# ----------------------------------------
# Pieces of data: 200000
# The length of List: 3303995
# Running time: 16.8194260597229 Seconds
# ----------------------------------------
# Pieces of data: 300000
# The length of List: 4952205
# Running time: 25.460472106933594 Seconds
# ----------------------------------------
# Pieces of data: 400000
# The length of List: 6602312
# Running time: 33.247819900512695 Seconds
# CPU times: user 36.4 s, sys: 1.76 s, total: 38.1 s
# Wall time: 39.9 s

# %%
#Vocabulary for predicting comments
vocabs_comment = sorted(list(set(Chracterlist_comment)))
comment_to_int = dict((c, i) for i, c in enumerate(vocabs_comment))   #Vectorize the text
int_to_comment = dict((i, c) for i, c in enumerate(vocabs_comment))
data_vocabs_comment=pd.DataFrame(data=vocabs_comment)#
data_vocabs_comment.to_csv('vocabs_comment.csv',encoding='gbk')

# %% [markdown]
# # Vectorization

# %% [markdown]
# Here we create 10 arrays to store the data for each stage. Because we need to keep inputing elements to our array and each time the array size grows, data migration occurs, which can be time-consuming. It took nearly two days when we first tried it. So we came up with this idea.

# %%
# %%time
start = time.time()
i = 0
for s in X:
    encoded_s = np.array([vocab_to_int[c] for c in toktok.tokenize(s)], dtype=np.int32)
    if encoded_s.shape[0]<50:
        l = encoded_s.shape[0]
        encoded_s = np.pad(encoded_s, (50-l,0), 'constant')
    else:
        encoded_s = encoded_s[:50]
    i = i+1    
    
    
    if i<50000:
        encoded1 = np.vstack((encoded1, encoded_s))
    elif i>=50000 and i<100000:
        encoded2 = np.vstack((encoded2, encoded_s))  
    elif i>=100000 and i<150000:   
        encoded3 = np.vstack((encoded3, encoded_s))         
    elif i>=150000 and i<200000:   
        encoded4 = np.vstack((encoded4, encoded_s))         
    elif i>=200000 and i<250000:   
        encoded5 = np.vstack((encoded5, encoded_s)) 
    elif i>=250000 and i<300000:   
        encoded6 = np.vstack((encoded6, encoded_s))         
    elif i>=300000 and i<350000:   
        encoded7 = np.vstack((encoded7, encoded_s))         
    elif i>=350000 and i<400000:   
        encoded8 = np.vstack((encoded8, encoded_s))
    elif i>=400000 and i<450000:   
        encoded9 = np.vstack((encoded9, encoded_s))        
    else:   
        encoded10 = np.vstack((encoded10, encoded_s))        
         
    if i % 100000 == 0:
        print('----------------------------------------')
        print('Pieces of data Processed: %s'%(i))
#         print('The Shape of Encoded Array: %s'% (encoded.shape,))
        end=time.time()
        print('Running time: %s Seconds'%(end-start))
# Out:
# ----------------------------------------
# Pieces of data Processed: 100000
# Running time: 489.3179728984833 Seconds
# ----------------------------------------
# Pieces of data Processed: 200000
# Running time: 951.5639998912811 Seconds
# ----------------------------------------
# Pieces of data Processed: 300000
# Running time: 1408.0064408779144 Seconds
# ----------------------------------------
# Pieces of data Processed: 400000
# Running time: 1871.5140528678894 Seconds
# CPU times: user 22min 22s, sys: 12min 44s, total: 35min 7s
# Wall time: 35min 14s
# Parser   : 146 ms

# %%
encoded11 = np.empty([50])
encoded12 = np.empty([50])
encoded13 = np.empty([50])
encoded14 = np.empty([50])
encoded15 = np.empty([50])
encoded16 = np.empty([50])
encoded17 = np.empty([50])
encoded18 = np.empty([50])
encoded19 = np.empty([50])
encoded20 = np.empty([50])

# %%
# %%time
start = time.time()
i = 0
for s in y[:,0]:
    encoded_s = np.array([vocab_to_int[c] for c in toktok.tokenize(s)], dtype=np.int32)
    if encoded_s.shape[0]<50:
        l = encoded_s.shape[0]
        encoded_s = np.pad(encoded_s, (50-l,0), 'constant')
    else:
        encoded_s = encoded_s[:50]
    i = i+1    
    
    
    if i<50000:
        encoded11 = np.vstack((encoded11, encoded_s))
    elif i>=50000 and i<100000:
        encoded12 = np.vstack((encoded12, encoded_s))  
    elif i>=100000 and i<150000:   
        encoded13 = np.vstack((encoded13, encoded_s))         
    elif i>=150000 and i<200000:   
        encoded14 = np.vstack((encoded14, encoded_s))         
    elif i>=200000 and i<250000:   
        encoded15 = np.vstack((encoded15, encoded_s)) 
    elif i>=250000 and i<300000:   
        encoded16 = np.vstack((encoded16, encoded_s))         
    elif i>=300000 and i<350000:   
        encoded17 = np.vstack((encoded17, encoded_s))         
    elif i>=350000 and i<400000:   
        encoded18 = np.vstack((encoded18, encoded_s))
    elif i>=400000 and i<450000:   
        encoded19 = np.vstack((encoded19, encoded_s))        
    else:   
        encoded20 = np.vstack((encoded20, encoded_s))        
         
    if i % 100000 == 0:
        print('----------------------------------------')
        print('Pieces of data Processed: %s'%(i))
#         print('The Shape of Encoded Array: %s'% (encoded.shape,))
        end=time.time()
        print('Running time: %s Seconds'%(end-start))
# Out:
# ----------------------------------------
# Pieces of data Processed: 100000
# Running time: 420.38994693756104 Seconds
# ----------------------------------------
# Pieces of data Processed: 200000
# Running time: 857.4740488529205 Seconds
# ----------------------------------------
# Pieces of data Processed: 300000
# Running time: 1293.0160129070282 Seconds
# ----------------------------------------
# Pieces of data Processed: 400000
# Running time: 1750.2411909103394 Seconds
# CPU times: user 20min 31s, sys: 13min 8s, total: 33min 39s
# Wall time: 33min 46s

# %% [markdown]
# After vectorization, merge sub-arrays into one

# %%
encodedx = np.vstack((np.delete(encoded1, [0], axis = 0), np.delete(encoded2, [0], axis = 0), np.delete(encoded3, [0], axis = 0), np.delete(encoded4, [0], axis = 0), np.delete(encoded5, [0], axis = 0), np.delete(encoded6, [0], axis = 0), np.delete(encoded7, [0], axis = 0), np.delete(encoded8, [0], axis = 0), np.delete(encoded9, [0], axis = 0), np.delete(encoded10, [0], axis = 0)))

# %%
encodedy = np.vstack((np.delete(encoded11, [0], axis = 0), np.delete(encoded12, [0], axis = 0), np.delete(encoded13, [0], axis = 0), np.delete(encoded14, [0], axis = 0), np.delete(encoded15, [0], axis = 0), np.delete(encoded16, [0], axis = 0), np.delete(encoded17, [0], axis = 0), np.delete(encoded18, [0], axis = 0), np.delete(encoded19, [0], axis = 0), np.delete(encoded20, [0], axis = 0)))

# %% [markdown]
# Save the vectorized data

# %%
data_encoded_x=pd.DataFrame(data=encodedx)#
data_encoded_x.to_csv('encodedx.csv',encoding='gbk')
data_encoded_y=pd.DataFrame(data=encodedy)#
data_encoded_y.to_csv('encodedy.csv',encoding='gbk')

# %% [markdown]
# ### Split dataset into training and testing

# %%
X_train_start = 0
X_train_end = int(np.floor(encodedx.shape[0]*0.9))
X_test_end = int(encodedx.shape[0])
Y_train_start = 0
Y_train_end = int(np.floor(encodedy.shape[0]*0.9))
Y_test_end = int(encodedy.shape[0])
X_train_encoded = X_encoded[X_train_start: X_train_end]
X_test_encoded = X_encoded[X_train_end: X_test_end]
Y_train_encoded = Y_encoded[Y_train_start: Y_train_end]
Y_test_encoded = Y_encoded[Y_train_end: Y_test_end]

# %% [markdown]
# Check the formats

# %%
print(X_train_encoded.shape)
print(Y_train_encoded.shape)
print(X_test_encoded.shape)
print(Y_test_encoded.shape)
# Out:
# (423437, 50)
# (423437, 50)
# (47049, 50)
# (47049, 50)

# %% [markdown]
# ## Create RNN Model and Generate Comments

# %%
# Import Tensorflow
import tensorflow as tf

# %%
# Number of features in training
n_code = X_train_encoded.shape[1]

# Neurons
n_neurons_1 = 1024
n_neurons_2 = 512
n_neurons_3 = 256
n_neurons_4 = 128

#Traget dimensions
n_target = 50

# %%
# Session
net = tf.InteractiveSession()

# %% [markdown]
# The shape of the placeholders correspond to [None, n_code] , meaning that the inputs and outputs are 2-dimensional matrix vector. And [None] means the size is undefined and can be defined later.

# %%
# Placeholder
X = tf.placeholder(dtype=tf.float32, shape=[None, n_code])
Y = tf.placeholder(dtype=tf.float32, shape=[None, n_code])

# %% [markdown]
# The ultimate goal of neural network training is to get the best parameters and make the target function get the minimum value. Initialization of parameters is also important.

# %%
# Initializers
sigma = 1
weight_initializer = tf.variance_scaling_initializer(mode="fan_avg", distribution="uniform", scale=sigma)
bias_initializer = tf.zeros_initializer()

# %% [markdown]
# Our model consists of 4 hidden layers and we define the amount in every layers from 1024 to 128. The number of neurons in each subsequent layer reduces the amount of information that the network identifies in the previous layer.

# %%
# Hidden weights
W_hidden_1 = tf.Variable(weight_initializer([n_code, n_neurons_1]))
bias_hidden_1 = tf.Variable(bias_initializer([n_neurons_1]))
W_hidden_2 = tf.Variable(weight_initializer([n_neurons_1, n_neurons_2]))
bias_hidden_2 = tf.Variable(bias_initializer([n_neurons_2]))
W_hidden_3 = tf.Variable(weight_initializer([n_neurons_2, n_neurons_3]))
bias_hidden_3 = tf.Variable(bias_initializer([n_neurons_3]))
W_hidden_4 = tf.Variable(weight_initializer([n_neurons_3, n_neurons_4]))
bias_hidden_4 = tf.Variable(bias_initializer([n_neurons_4]))

# %% [markdown]
# Weights and biases are represented as variables in order to adapt during training.

# %%
# Output weights
W_out = tf.Variable(weight_initializer([n_neurons_4, n_target]))
bias_out = tf.Variable(bias_initializer([n_target]))

# %% [markdown]
# Activation functions are important elements. Because without the Activation function, the multi-layer inputs and ouputs are just in a linear transformation. Since the expression ability of linear model is not enough, the Activation function can introduce nonlinear factors.
#
# We choose ReLU(Rectified Linear Unit) in our model, one of the most common Activation functions.

# %%
# # Hidden layer
# hidden_1 = tf.nn.relu(tf.add(tf.matmul(X, W_hidden_1), bias_hidden_1))
# hidden_2 = tf.nn.relu(tf.add(tf.matmul(hidden_1, W_hidden_2), bias_hidden_2))
# hidden_3 = tf.nn.relu(tf.add(tf.matmul(hidden_2, W_hidden_3), bias_hidden_3))
# hidden_4 = tf.nn.relu(tf.add(tf.matmul(hidden_3, W_hidden_4), bias_hidden_4))
# # Output layer (transpose to fit the shape!)
# out = tf.transpose(tf.add(tf.matmul(hidden_4, W_out), bias_out))

# %%
model = Sequential()

model.add(Conv2D(128, (3, 3), strides=(1,1), padding='same', 
					input_shape=x_train.shape[1:]))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same'))
model.add(Activation('relu'))

model.add(Conv2D(128, (3, 3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same'))

model.add(Conv2D(128, (3, 3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same'))

model.add(Conv2D(256, (3, 3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), strides=(1,1), padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding='same'))

# 3 Fully connect Layer
model.add(Flatten())
model.add(Dense(4096))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(1024))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
# Cost function
mse = tf.reduce_sum(tf.reduce_mean(tf.squared_difference(tf.transpose(out), Y)))

# %% [markdown]
# The learning rate is inversely proportional to the number of layers in the network. The more layers there are, the lower the learning rate is.
#
# If the learning rate is too high, the loss begins to increase and then diverges to infinity

# %% [markdown]
# Deep learning is common for gradient optimization, that is to say, the optimizer is actually all kinds of gradient descent algorithm optimization. It indicates the direction in which the weights and biases have to be changed during training in order to minimize the network’s cost function.

# %% [markdown]
# Adam(adaptive moment estimation) dynamically adjusts the learning rate of each parameter according to the first moment estimation and the second moment estimation of the gradient of each parameter based on the loss function. TensorFlow offers tf.train.adamoptimizer to control the learning speed. Adam is also a method based on gradient descent, but the learning step size of parameters in each iteration has a certain range, which will not lead to a large learning step size due to a large gradient. The value of parameters is relatively stable.

# %%
# Optimizer
# Adam
learning_rate = 0.0005
opt = tf.train.AdamOptimizer(learning_rate).minimize(mse)

# %%
# Run initializer
net.run(tf.global_variables_initializer())

# %%
init = tf.global_variables_initializer()

# %%
# Batch size
batch_size = 256
mse_train = []
mse_test = []

# %%
# %%time
epochs = 100 #number of iterations or training cycles

saver = tf.train.Saver(max_to_keep=4)
with tf.Session() as sess:
    init.run()
    for e in range(epochs):
        sess.run(opt, feed_dict={X: X_train_encoded, Y: Y_train_encoded})
        if e % 10 == 0:
            print("-----------------------")
            loss = mse.eval(feed_dict={X: X_train_encoded, Y: Y_train_encoded})
            print(e, "\tMSE:", loss)
            print("----------save the model")
            saver.save(sess, "model/my-model", global_step=e)   
    y_pred = sess.run(out, feed_dict={X: X_test_encoded})
# Out:
# -----------------------
# 0 	MSE: 4.16052e+11
# ----------save the model
# -----------------------
# 10 	MSE: 3.41653e+11
# ----------save the model
# -----------------------
# 20 	MSE: 2.99512e+11
# ----------save the model
# -----------------------
# 30 	MSE: 2.77965e+11
# ----------save the model
# -----------------------
# 40 	MSE: 2.61161e+11
# ----------save the model
# -----------------------
# 50 	MSE: 2.50663e+11
# ----------save the model
# -----------------------
# 60 	MSE: 2.4382e+11
# ----------save the model
# -----------------------
# 70 	MSE: 2.40229e+11
# ----------save the model
# -----------------------
# 80 	MSE: 2.38388e+11
# ----------save the model
# -----------------------
# 90 	MSE: 2.37596e+11
# ----------save the model
# CPU times: user 2h 36min 13s, sys: 13min 59s, total: 2h 50min 13s
# Wall time: 28min

# %% [markdown]
# ## Decoding Prediction Results

# %% [markdown]
# We store the decoded comments in list Comment_pred, and merge prediction data and test data to check the accuracy.

# %%
y_pred = y_pred.T

# %%
import string
length = y_pred.shape[0]
Comment_pred = []
for x in y_pred:
    comment = ''
    for y in x:
        try:
            co = int_to_comment[int(y)]
        except:
            continue
        co = co.strip(string.punctuation)    
        comment = comment+' '+co
    
    Comment_pred = Comment_pred + [comment]

# %%
Comment_pred = np.array(Comment_pred)

# %%
y = rawdata[:, 1:]
Comment_test = y[:,0][Y_train_end: Y_test_end]
Test_result = np.vstack((Comment_test, Comment_pred)).T

# %%
Result=pd.DataFrame(data=Test_result, columns = ['Comment','Prediction'])#
Result
# Out:
#                                                  Comment  \
# 0          <!-- begin-user-doc --> <!-- end-user-doc -->
# 1      The default flow direction. Normally (which is...
# 2      Size the window and positioning it relative to...
# 3      Returns the contents of the cell at rowNumber ...
# 4                                Method strategyStarted.
# 5      Checks if this column is signed. It always ret...
# 6      Merges authorization configurations by putting...
# 7          <!-- begin-user-doc --> <!-- end-user-doc -->
# 8      Synchronized read of the current number of tas...
# 9      Schedule a task for repeated fixed-rate execut...
# 10                                     Scrolls the wheel
# 11     to unload units, a bay must have more doors av...
# 12     Used by the Whitebox GUI to tell if this plugi...
# 13     nextLong(bound) returns 0 <= value < bound; re...
# 14                                        Format an int.
# 15     Creates the searched query using given named q...
# 16     Create a space for the given tonnage of troops...
# 17                Returns the tip text for this property
# 18                                         Print it all.
# 19     This method checks a patch object for validity...
# 20     Creates new SPI exception given throwable as a...
# 21     Terminates the current line by printing the li...
# 22     Factory method for constructing an empty JSON ...
# 23                                         Drag and drop
# 24           Return if the vertex is a system primitive.
# 25     Verify if storage capacity currently used has ...
# 26     Handles exceptions. <p> OkHttp notifies caller...
# 27      Creates the ReaderSource from a File descriptor.
# 28         Utility classes should never be instantiated.
# 29         Returns the index of the first valid element.
# ...                                                  ...
# 47019  Identify where the start of the middle / paylo...
# 47020  Returns <code>true</code> if an array contains...
# 47021  Some properties of acosh(x) = log(x + sqrt(x^2...
# 47022            Create and fire Data Status Error Event
# 47023                    Create new AttributeDefinition.
# 47024  Consumes a substring from the current sval of ...
# 47025  Converts a hex string into a decimal number an...
# 47026         Locates and decodes a QR code in an image.
# 47027                     Get a list of backup sets info
# 47028                  Creates a CountingIdlingResource.
# 47029             Find out the size list can be re-sued.
# 47030  Synchronize a region of memory: force data in ...
# 47031  Creates a new instance for the specified time ...
# 47032  Confirm behavior when connector.security.use.S...
# 47033                    Adds a new value to the series.
# 47034  This method is called when a fatal error occur...
# 47035                  Used to execute this plugin tool.
# 47036  Invoke this method to add additional component...
# 47037  Creates a progress timer with the texture as t...
# 47038      <!-- begin-user-doc --> <!-- end-user-doc -->
# 47039  Returns the result of the last matching operat...
# 47040  Sends an IEvent to all listeners that listen f...
# 47041                       Creates the mouth combo box.
# 47042  Outputs the leverage for a rule. Leverage is d...
# 47043                    Creates a new RdKNNNode object.
# 47044  Adapts the height of the grid view, which is u...
# 47045  Validates the arguments passed to the Builder ...
# 47046           whether check errors as more as possible
# 47047  Creates a new instance of the New Playlist dia...
# 47048  Report the current cursor location in its window.
#
#                                               Prediction
# 0       Business mca tt>iface</tt code>_gfortran_abor...
# 1       code>Vector</code IINCs code>s2</code subDire...
# 2       OpenMRS ADWIN code>foreach</code CWD bR Eleme...
# 3       beHealthyMember 0x00080003</li ValidationErro...
# 4       code>retryCount</code PKCS1 code>t</code IntA...
# 5       CopyStreamListener owner-write desactive exam...
# 6       code>hrs</code patient fetch defineFont imple...
# 7       consults finalized Gmail 21/#F2 gm PUSHF code...
# 8       Vissim-Inp-File Notice li>Scan DirectedGraph ...
# 9       code>XmlWriter</code fValue RiskoGefaehrdungs...
# 10      expectedNumNodes CodeSearchClient EnclosingMe...
# 11      Repulsively code>parameter</code LM=115645985...
# 12      DiscFolders HDN tt>YY_INITIAL</tt i>Lecture E...
# 13      i>union</i field-info PCAPImportTask CUDA_POI...
# 14      getter/setter/with editText BalanceStrategy A...
# 15      file/snapshots SO_TIMEOUT choke chromsosomes ...
# 16      QueueCircuitBreakerConfigurationResource Hexa...
# 17      ExtendedCoordinateSequence code>persistName</...
# 18      computeSdkRegistrantsKeyV2 LookupInfo Nation-...
# 19      Initiliaze Alter Kernel32 code>setSelectedTex...
# 20      Hibernate EvalException DummyStatisticsFactor...
# 21      GenreGrouperMediaFileNode FileSnapshot em>Pre...
# 22      Happened-before code>generateKeyPair code>DEA...
# 23      Differ non-Locals code>method</code coveringR...
# 24      Owner</em E-Mails 1-Q Kuznechik BeanCommon Ki...
# 25      002 pollution adhering border LoopyBP.createF...
# 26      SimpleImageContentProposalLabelProvider GetCh...
# 27      NAF One-based MultiStopsGradient BINARY_CLASS...
# 28      tt>_local</tt em>Speed</em BPartner Ljava/lan...
# 29      GB ExpandoMetaClassCreationHandle arcosecant ...
# ...                                                  ...
# 47019   code>decode builder-style MemberExpression.Ta...
# 47020   37</code MD5-hashed OpenSearchDescriptionDocu...
# 47021   channelId uniqueMember SupportedHeader first+...
# 47022   CatalystQueueConfiguration p>Conditionally B7...
# 47023   PAN Has Lift-Up AnnotatedElement broadest DDF...
# 47024   JvmRuntime cPSuri added.</li PortalPage GateL...
# 47025   Set<String ImageDecoder isLogin keystroke All...
# 47026   Days Interest StackOverflow</a absent-resourc...
# 47027   Memoize TopKSort SCROLL_TAB_LAYOUT actual-cou...
# 47028   LoopArrow String/int/char Trx ACTION_DISABLE ...
# 47029   code>rect</code DatePicker.isDateAllowed MBDe...
# 47030   Asume Datasources CENTER IWmsLayer inclinatio...
# 47031   code>defaultValue</code DragPane GMT Durbin-W...
# 47032   ELResolver cambio https://tools.ietf.org/html...
# 47033   CHARINDEX li>JScrollPane.COLUMN_HEADER CSSNav...
# 47034   Unmarshall getSku AnyType PostfixExpression.P...
# 47035   Decimates TlsRsaPremasterSecretParameterSpec ...
# 47036   cape SSLMicroNetworkModule TaskResourceRep tt...
# 47037   code>WAND</code Forms CygwinTerminal Identity...
# 47038   code>persistLocation</code Zq code>SpringLayo...
# 47039   FileNo Volley genericTypeIndex ParameterizedP...
# 47040   Span APP14 Pibrella inputSet.isPicking sigma ...
# 47041   Client-side li>0XaaRRggBb</li code>readFully<...
# 47042   1992 Ssl search/weights ProtectionSet RFC1519...
# 47043   ErrorHandler.fatalError tt>ParameterizedLinke...
# 47044   StringUtil.quoteIdentifier ABOF code>output</...
# 47045   code>RefactoringStatus</code VmStateHistoryEn...
# 47046   QacR CasCopier Monitor.hasListeners code>prep...
# 47047   code>HGtypeSystem</code cloneFromSnapshotSupp...
# 47048   ReplicateScaleFilter arg0 eleminates Orthogon...
#
# [47049 rows x 2 columns]

# %% [markdown]
# ## Evaluate results by BLEU-4

# %% [markdown]
# We evaluate our results through nltk-bleu scoring method and get scores.

# %%
from nltk.translate.bleu_score import sentence_bleu

# %%
scores = []
for i in range(Comment_test.shape[0]):
    reference = toktok.tokenize(Comment_test[i])
    candidate = toktok.tokenize(Comment_pred[i])
    score = sentence_bleu(reference, candidate)
    scores = scores + [score]
# Out:
# /anaconda3/lib/python3.5/site-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)

# %%
scores = np.array(scores)
Final_result = np.concatenate(([scores],Test_result.T)).T
Final_Result=pd.DataFrame(data=Final_result, columns = ['Score','Prediction','Comment'])#
Final_Result
# Out:
#           Score                                         Prediction  \
# 0             0      <!-- begin-user-doc --> <!-- end-user-doc -->
# 1             0  The default flow direction. Normally (which is...
# 2             0  Size the window and positioning it relative to...
# 3             0  Returns the contents of the cell at rowNumber ...
# 4             0                            Method strategyStarted.
# 5             0  Checks if this column is signed. It always ret...
# 6             0  Merges authorization configurations by putting...
# 7             0      <!-- begin-user-doc --> <!-- end-user-doc -->
# 8             0  Synchronized read of the current number of tas...
# 9             0  Schedule a task for repeated fixed-rate execut...
# 10            0                                  Scrolls the wheel
# 11            0  to unload units, a bay must have more doors av...
# 12            0  Used by the Whitebox GUI to tell if this plugi...
# 13            0  nextLong(bound) returns 0 <= value < bound; re...
# 14            0                                     Format an int.
# 15            0  Creates the searched query using given named q...
# 16            0  Create a space for the given tonnage of troops...
# 17            0             Returns the tip text for this property
# 18            0                                      Print it all.
# 19            0  This method checks a patch object for validity...
# 20            0  Creates new SPI exception given throwable as a...
# 21            0  Terminates the current line by printing the li...
# 22            0  Factory method for constructing an empty JSON ...
# 23     0.472871                                      Drag and drop
# 24            0        Return if the vertex is a system primitive.
# 25            0  Verify if storage capacity currently used has ...
# 26            0  Handles exceptions. <p> OkHttp notifies caller...
# 27            0   Creates the ReaderSource from a File descriptor.
# 28            0      Utility classes should never be instantiated.
# 29            0      Returns the index of the first valid element.
# ...         ...                                                ...
# 47019         0  Identify where the start of the middle / paylo...
# 47020         0  Returns <code>true</code> if an array contains...
# 47021         0  Some properties of acosh(x) = log(x + sqrt(x^2...
# 47022  0.434721            Create and fire Data Status Error Event
# 47023         0                    Create new AttributeDefinition.
# 47024         0  Consumes a substring from the current sval of ...
# 47025         0  Converts a hex string into a decimal number an...
# 47026         0         Locates and decodes a QR code in an image.
# 47027         0                     Get a list of backup sets info
# 47028         0                  Creates a CountingIdlingResource.
# 47029         0             Find out the size list can be re-sued.
# 47030         0  Synchronize a region of memory: force data in ...
# 47031         0  Creates a new instance for the specified time ...
# 47032         0  Confirm behavior when connector.security.use.S...
# 47033         0                    Adds a new value to the series.
# 47034         0  This method is called when a fatal error occur...
# 47035         0                  Used to execute this plugin tool.
# 47036         0  Invoke this method to add additional component...
# 47037         0  Creates a progress timer with the texture as t...
# 47038         0      <!-- begin-user-doc --> <!-- end-user-doc -->
# 47039         0  Returns the result of the last matching operat...
# 47040         0  Sends an IEvent to all listeners that listen f...
# 47041         0                       Creates the mouth combo box.
# 47042         0  Outputs the leverage for a rule. Leverage is d...
# 47043         0                    Creates a new RdKNNNode object.
# 47044         0  Adapts the height of the grid view, which is u...
# 47045         0  Validates the arguments passed to the Builder ...
# 47046         0           whether check errors as more as possible
# 47047         0  Creates a new instance of the New Playlist dia...
# 47048         0  Report the current cursor location in its window.
#
#                                                  Comment
# 0       Business mca tt>iface</tt code>_gfortran_abor...
# 1       code>Vector</code IINCs code>s2</code subDire...
# 2       OpenMRS ADWIN code>foreach</code CWD bR Eleme...
# 3       beHealthyMember 0x00080003</li ValidationErro...
# 4       code>retryCount</code PKCS1 code>t</code IntA...
# 5       CopyStreamListener owner-write desactive exam...
# 6       code>hrs</code patient fetch defineFont imple...
# 7       consults finalized Gmail 21/#F2 gm PUSHF code...
# 8       Vissim-Inp-File Notice li>Scan DirectedGraph ...
# 9       code>XmlWriter</code fValue RiskoGefaehrdungs...
# 10      expectedNumNodes CodeSearchClient EnclosingMe...
# 11      Repulsively code>parameter</code LM=115645985...
# 12      DiscFolders HDN tt>YY_INITIAL</tt i>Lecture E...
# 13      i>union</i field-info PCAPImportTask CUDA_POI...
# 14      getter/setter/with editText BalanceStrategy A...
# 15      file/snapshots SO_TIMEOUT choke chromsosomes ...
# 16      QueueCircuitBreakerConfigurationResource Hexa...
# 17      ExtendedCoordinateSequence code>persistName</...
# 18      computeSdkRegistrantsKeyV2 LookupInfo Nation-...
# 19      Initiliaze Alter Kernel32 code>setSelectedTex...
# 20      Hibernate EvalException DummyStatisticsFactor...
# 21      GenreGrouperMediaFileNode FileSnapshot em>Pre...
# 22      Happened-before code>generateKeyPair code>DEA...
# 23      Differ non-Locals code>method</code coveringR...
# 24      Owner</em E-Mails 1-Q Kuznechik BeanCommon Ki...
# 25      002 pollution adhering border LoopyBP.createF...
# 26      SimpleImageContentProposalLabelProvider GetCh...
# 27      NAF One-based MultiStopsGradient BINARY_CLASS...
# 28      tt>_local</tt em>Speed</em BPartner Ljava/lan...
# 29      GB ExpandoMetaClassCreationHandle arcosecant ...
# ...                                                  ...
# 47019   code>decode builder-style MemberExpression.Ta...
# 47020   37</code MD5-hashed OpenSearchDescriptionDocu...
# 47021   channelId uniqueMember SupportedHeader first+...
# 47022   CatalystQueueConfiguration p>Conditionally B7...
# 47023   PAN Has Lift-Up AnnotatedElement broadest DDF...
# 47024   JvmRuntime cPSuri added.</li PortalPage GateL...
# 47025   Set<String ImageDecoder isLogin keystroke All...
# 47026   Days Interest StackOverflow</a absent-resourc...
# 47027   Memoize TopKSort SCROLL_TAB_LAYOUT actual-cou...
# 47028   LoopArrow String/int/char Trx ACTION_DISABLE ...
# 47029   code>rect</code DatePicker.isDateAllowed MBDe...
# 47030   Asume Datasources CENTER IWmsLayer inclinatio...
# 47031   code>defaultValue</code DragPane GMT Durbin-W...
# 47032   ELResolver cambio https://tools.ietf.org/html...
# 47033   CHARINDEX li>JScrollPane.COLUMN_HEADER CSSNav...
# 47034   Unmarshall getSku AnyType PostfixExpression.P...
# 47035   Decimates TlsRsaPremasterSecretParameterSpec ...
# 47036   cape SSLMicroNetworkModule TaskResourceRep tt...
# 47037   code>WAND</code Forms CygwinTerminal Identity...
# 47038   code>persistLocation</code Zq code>SpringLayo...
# 47039   FileNo Volley genericTypeIndex ParameterizedP...
# 47040   Span APP14 Pibrella inputSet.isPicking sigma ...
# 47041   Client-side li>0XaaRRggBb</li code>readFully<...
# 47042   1992 Ssl search/weights ProtectionSet RFC1519...
# 47043   ErrorHandler.fatalError tt>ParameterizedLinke...
# 47044   StringUtil.quoteIdentifier ABOF code>output</...
# 47045   code>RefactoringStatus</code VmStateHistoryEn...
# 47046   QacR CasCopier Monitor.hasListeners code>prep...
# 47047   code>HGtypeSystem</code cloneFromSnapshotSupp...
# 47048   ReplicateScaleFilter arg0 eleminates Orthogon...
#
# [47049 rows x 3 columns]

# %%
Final_Result[Final_Result['Score']>0]
# Out:
#           Score                                         Prediction  \
# 23     0.472871                                      Drag and drop
# 92     0.456634  Put string data to shared preferences in priva...
# 185    0.423799  Creates an empty set of values using the defau...
# 228    0.415677          Always throws RejectedExecutionException.
# 250    0.447214                                    Action Listener
# 335    0.492479  Strips source routing. According to RFC-2821 i...
# 347    0.467138  <p>Search the specified classloader for the gi...
# 419    0.447214              Mouse Clicked. Start AssignmentDialog
# 475    0.434721  Checks whether this line in the cql script ind...
# 503    0.417226      Has this upstream started or "onSubscribed" ?
# 524    0.447214  Encode the value using DoubleMetaphone.  It wi...
# 529    0.456634  Helper method to create a note synchronously i...
# 583     0.57735  Runs the given runnable on the user interface ...
# 589    0.478974  Indicates whether we are in touch mode. Callin...
# 621    0.451801  Return a bit mask of the differences between t...
# 645    0.451801  cast a double value to a Float Object(referenc...
# 654    0.472871  Get the length of matrix Do level by level, ea...
# 685    0.456634  Returns a hash code for the object. This metho...
# 705    0.456634                       Creates a new syntax scheme.
# 776    0.492479  Compare two double arrays using a given tolerance
# 789    0.434721                   Converts dp value to pixel value
# 790    0.438691  The <code>commit</code> method is used flush a...
# 828    0.427287  Use this method to ignore the next incoming SO...
# 869    0.485492  Analyse vertex and traverse its relationships....
# 1020    0.44285  Create an instance of BatteryInfo initialized ...
# 1026   0.434721  <p>Construct a new exception with the specifie...
# 1032   0.427287                             creates a new factory.
# 1048   0.334719  Tests fix for BUG#19615, PreparedStatement.set...
# 1050   0.478974      Construct a runner from the provided options.
# 1077   0.430924                            Generate a single DBID.
# ...         ...                                                ...
# 45899  0.456634               Application execution implementation
# 45945  0.451801                                Deploy datasources.
# 45968  0.438691            Create a new ChallengeMovementListener.
# 45979  0.451801  Creates an instance of <code>JOptionPane</code...
# 46047  0.461737  Report version information about JAXP interfac...
# 46063  0.622333  Copy device content into vfs. All imported con...
# 46186  0.478974  Converts a screen coordinate spaced shape to t...
# 46192  0.367867  ReleaseBooleanArrayElements: free the native c...
# 46195  0.467138                                   Initialize Panel
# 46214  0.423799  Examine message to see if it is an asynchronou...
# 46290  0.478974          Initializes using the supplied skin file.
# 46321  0.485492  Computes the minimum probability along the mos...
# 46327  0.434721  Creates an inner operator condition. The first...
# 46334  0.467138  Prints the MI matrix to a given output stream....
# 46385  0.492479  removes the specified strategy from this manag...
# 46414  0.434721  Return an Iterator of all children of this nod...
# 46424  0.461737  Constructs a new instanted model editor from a...
# 46473  0.461737  Asks the camera hardware to perform an autofocus.
# 46487  0.447214  Execute the function.  The function must retur...
# 46512  0.461737  Sets bounding box of all elements in group at ...
# 46556  0.467138  Guarantees that the conversation has been crea...
# 46564  0.451801  Check to make sure that the provided speechlet...
# 46611  0.451801  Method to be implemented that builds the corre...
# 46643  0.456634  Converts the specified long value into its hex...
# 46740  0.451801              Cancels the subscription permanently.
# 46756  0.492479     Blends one area of this image to another area.
# 46808  0.478974  Extracts the SDO_ELEM_INFO interpretation valu...
# 46916  0.451801  Add a unique edge to the graph. There must be ...
# 46979  0.472871  Sorts the given array slice in natural order. ...
# 47022  0.434721            Create and fire Data Status Error Event
#
#                                                  Comment
# 23      Differ non-Locals code>method</code coveringR...
# 92      Caret dl_vlan m lockGrantorIdLock DTLZ fist i...
# 185     1111 li>user=username</li AuthnProviderParams...
# 228     DownloadStatusConfiguration MapKey MediaRoute...
# 250     breaker 1e-13ish MessagingArea tt>target.size...
# 335     LOCALAWARE_CLUSTERPERSISTENT CommandsWindow r...
# 347     FailedTask Initialitzes LogReaderTask prefix ...
# 419     code>quad.properties</code code>InvalidJobExc...
# 475     Pnts SSDP tt>ras</tt complied bootrecord Tran...
# 503     HGAtomRef JDlgUploadProducts tt>other</tt>val...
# 524     Inits Receipts EM>No MemberExpression.Indexed...
# 529     InReplyToParser ShowUsesHandler customzing Id...
# 583     HIGHEST_TIER Bug#22848249 XBLOMDefinitionElem...
# 589     AROW porterduff localhost DMOZ WrappedSocket ...
# 621     li>Rathaus li>r ScriptGroup s GamaList getNot...
# 645     BlockGroup BY Servlet/JSP DelegatingServletOu...
# 654     1.0+Math.pow commented-out Bug#41532 code>pre...
# 685     li><code>levenstein</code RootStatement<Yield...
# 705     WhitenedZCA codfe>getTrustedCertificate HDFS ...
# 776     https://openwms.atlassian.net/wiki/x/BIAWAQ d...
# 789     Math.PI MoveValidator MSB TestAssertion andro...
# 790     li>\r</li code>stateInXml</code V1.V2 MLSD UN...
# 828     NoProxySelector L<sub>1</sub RuntimeException...
# 869     cd467dc12a42d588638aaab06746bebdfb333cc4 rebo...
# 1020    l curation p>Stops ClassDetail AnnotatedN4Mem...
# 1026    BugInstanceGroup Repositions EsriPolylineList...
# 1032    code>pFileOrDirectory</code Instruments KeyCh...
# 1048    NativeTitanGraphQuery ZkIndexSchemaReader 8.2...
# 1050    esquerda 0*d multi-terms domain-dirs dijkstra...
# 1077    ID=Wilf CreateSchemaObject Durham JTabbedPane...
# ...                                                  ...
# 45899   representation c p>Some http://en.wikipedia.o...
# 45945   RDFT s PayAmt segment beans N_FunctionDefinit...
# 45968   LibSVM De-serializes ForegroundAction WebView...
# 45979   AccountCreationRules INTEGERS neurons Closeab...
# 46047   p>New TripPattern KD MaterialPreviewWidget Li...
# 46063   BaseType o LongMap clearCache signerIdentifie...
# 46186   Gen model2 XMLNormalize SystemPermission mini...
# 46192   6.5.2 Reject Abbreviated CTGAAGCTGTCACCGGATGT...
# 46195   expr=AbstractRef InnerTokenize certificates.<...
# 46214   code>colladaSource</code code>playground.piet...
# 46290   tt>filename</tt PARTYMGR_UPDATE OPTIONALs p R...
# 46321   Fullpath device.</p CLnnnBxxxx p crlNumber Up...
# 46327   LeftHandSideExpression.ParameterizedCallExpre...
# 46334   General CDCR Remittance TOOL_TYPE_FINGER java...
# 46385   setText VolumePanel RTEditText.BOLD li>T*T re...
# 46414   BluetoothLEController code>readResolve</code ...
# 46424   Originally Halt a Rollout Negocia boarding/al...
# 46473   u detailText RightParen Independent moduleSpe...
# 46487   code>magnitude</code ExportMaskOperations Hov...
# 46512   li>ScrollPaneConstants.HORIZONTAL_SCROLLBAR 2...
# 46556   em>Please Via font PImage IntSetting barath c...
# 46564   parentX ILOAD_&lt code>logSegmentSeqNo</code ...
# 46611   ROOT_LOGGER USUBADDX ServiceManagementRecord ...
# 46643   a code>Javadoc</code GroupReferences FetchReq...
# 46740   IntArgbPre tt>WKTFileReader</tt tt>trafficCla...
# 46756   em>SLoop</em decimal-dotted JetstreamApplicat...
# 46808   NoSuchProviderException negotiatedQop QueryDa...
# 46916   code>setBoolean</code Induced JniStream Thous...
# 46979   OpenNLP A\n KeyStore.Builder DViewPublicKey L...
# 47022   CatalystQueueConfiguration p>Conditionally B7...
#
# [1579 rows x 3 columns]

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The model had difficulties with this dataset, as the achieved accuracy was relatively low. However, the performance of this vectorization approach mainly relies on the dataset, and it still has much room for improvement.

# %% [markdown]
# ## Reference

# %% [markdown]
# [1] Xing Hu, Ge li, Zhi Jin. Deep Code Comment Generation. 2018. Key Laboratory of High Confidence Software Technologies (Peking University), MoE.
#
# [2] Tjalling Haije. Automatic Comment Generation using a Neural Translation Model. 2016. University of Amsterdam Faculty of Science.
#
# [3] A. Graves, “Sequence transduction with recurrent neural networks,” arXiv preprint arXiv:1211.3711, 2012.
