# %%
# %matplotlib inline
from collections import Counter
import random

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
train_data=pd.read_json('data/train.json',lines=True)
test_data=pd.read_json('data/test.json',lines=True)

# %%
train_data.dropna()
train_data
# Out:
#                                                      code  \
# 0                         protected void tearDown(){\n}\n
# 1       @KnownFailure("Fixed on DonutBurger, Wrong Exc...
# 2       public static CstFloat make(int bits){\n  retu...
# 3       public long size(){\n  long size=0;\n  if (par...
# 4       public void increment(View view){\n  if (quant...
# 5       public void trimToSize(){\n  ++modCount;\n  if...
# 6       public SyncValueResponseMessage(SyncValueRespo...
# 7       public void clearParsers(){\n  if (parserManag...
# 8       @Override public void run(){\n  while (doWork)...
# 9       private byte[] calculateUValue(byte[] generalK...
# 10      private void assign(HashMap<String,DBIDs> labe...
# 11      private void showFeedback(String message){\n  ...
# 12      public CDeleteAction(final BackEndDebuggerProv...
# 13      public Yaml(BaseConstructor constructor,Repres...
# 14      public void testHitEndAfterFind(){\n  hitEndTe...
# 15      public void add(Individual individual){\n  ind...
# 16      public boolean removeSession(IgniteUuid sesId)...
# 17      public static Bitmap loadBitmapOptimized(Uri u...
# 18      protected BasePeriod(long duration){\n  super(...
# 19        public FlatBufferBuilder(){\n  this(1024);\n}\n
# 20      public PbrpcConnectionException(String arg0,Th...
# 21      public void uninstallUI(JComponent a){\n  for ...
# 22      public static void shutdown(){\n  if (instance...
# 23      public boolean GE(Word w2){\n  return value.GE...
# 24      public static UnionCoder of(List<Coder<?>> ele...
# 25      public void testFileDeletion() throws Exceptio...
# 26      public boolean isOnClasspath(String classpath)...
# 27      protected void source(String ceylon){\n  Strin...
# 28      public PerformanceMonitor(){\n  initComponents...
# 29      @DSGenerator(tool_name="Doppelganger",tool_ver...
# ...                                                   ...
# 470456  int[] decodeStart(BitArray row) throws NotFoun...
# 470457  public static boolean contains(int[] array,int...
# 470458  public static double acosh(final double value)...
# 470459  public void fireDataStatusEEvent(String AD_Mes...
# 470460  AttributeDefinition(TextAttributeSet attrs,int...
# 470461  public void consumeGreedy(String greedyToken){...
# 470462  public static int hexToDecimal(String hex) thr...
# 470463  @Override public Result decode(BinaryBitmap im...
# 470464  public BackupFileSet listRawBackup(final boole...
# 470465  public CountingIdlingResource(String resourceN...
# 470466  public ImageReuseInfo create(String thisSize){...
# 470467  public static void sync(Address address,int si...
# 470468  public MonthDateFormat(Locale locale){\n  this...
# 470469  public void testConnectorSecuritySettingsSSL_a...
# 470470  public synchronized void add(double x,double y...
# 470471  public void fatalError(SAXParseException excep...
# 470472  @Override public void run(){\n  amIActive=true...
# 470473  public static void addMoreComponents(Container...
# 470474  public static CCProgressTimer progress(CCTextu...
# 470475  protected EntityMappingModelImpl(){\n  super()...
# 470476  public MatchResult match(){\n  if (!matchSucce...
# 470477  @Override public void dispatch(IEvent event){\...
# 470478  JComboBox createMouthComboBox(){\n  JComboBox ...
# 470479  public double leverageForRule(AprioriItemSet p...
# 470480  public RdKNNNode(int capacity,boolean isLeaf){...
# 470481  private void adaptGridViewHeight(){\n  if (gri...
# 470482  protected void validateOnStatus(){\n  if (Comm...
# 470483  public Optional<Boolean> eagerCheck(){\n  retu...
# 470484  public static NewPlaylistFragment newInstance(...
# 470485  @DSSink({DSSinkKind.LOG}) @DSGenerator(tool_na...
#
#                                                        nl
# 0       Tears down the fixture, for example, close a n...
# 1       javax.net.ssl.SSLEngine#unwrap(ByteBuffer src,...
# 2       Makes an instance for the given value. This ma...
# 3       Returns the "size" of the chromosome, namely, ...
# 4       This method is called when the plus button is ...
# 5       Trims the capacity of this <tt>ArrayHashList</...
# 6                   Performs a deep copy on <i>other</i>.
# 7                Removes all parsers from this text area.
# 8       This is the code for the thread. It delivers d...
# 9       Calculate what the U value should consist of g...
# 10      Assigns the specified id to the labelMap accor...
# 11      Used to communicate feedback pop-up messages b...
# 12                           Creates a new action object.
# 13      Create Yaml instance. It is safe to create a f...
# 14                       Regression test for HARMONY-4396
# 15                              Adds a single individual.
# 16                Removes session for a given session ID.
# 17      Loading bitmap with optimized loaded size less...
# 18      Creates a period from the given millisecond du...
# 19      Start with a buffer of 1KiB, then grow as requ...
# 20      Creates a new instance of PbrpcConnectionExcep...
# 21      Invokes the <code>uninstallUI</code> method on...
# 22                          Saves the configuration file.
# 23                       Greater-than or equal comparison
# 24      Builds a union coder with the given list of el...
# 25              Verify ability to delete a list of files.
# 26      Evaluates if the Dependency is targeted for a ...
# 27      Checks that we can still compile a client afte...
# 28                    Creates new form PerformanceMonitor
# 29              Wakes up node's successor, if one exists.
# ...                                                   ...
# 470456  Identify where the start of the middle / paylo...
# 470457  Returns <code>true</code> if an array contains...
# 470458  Some properties of acosh(x) = log(x + sqrt(x^2...
# 470459            Create and fire Data Status Error Event
# 470460                    Create new AttributeDefinition.
# 470461  Consumes a substring from the current sval of ...
# 470462  Converts a hex string into a decimal number an...
# 470463         Locates and decodes a QR code in an image.
# 470464                     Get a list of backup sets info
# 470465                  Creates a CountingIdlingResource.
# 470466             Find out the size list can be re-sued.
# 470467  Synchronize a region of memory: force data in ...
# 470468  Creates a new instance for the specified time ...
# 470469  Confirm behavior when connector.security.use.S...
# 470470                    Adds a new value to the series.
# 470471  This method is called when a fatal error occur...
# 470472                  Used to execute this plugin tool.
# 470473  Invoke this method to add additional component...
# 470474  Creates a progress timer with the texture as t...
# 470475      <!-- begin-user-doc --> <!-- end-user-doc -->
# 470476  Returns the result of the last matching operat...
# 470477  Sends an IEvent to all listeners that listen f...
# 470478                       Creates the mouth combo box.
# 470479  Outputs the leverage for a rule. Leverage is d...
# 470480                    Creates a new RdKNNNode object.
# 470481  Adapts the height of the grid view, which is u...
# 470482  Validates the arguments passed to the Builder ...
# 470483           whether check errors as more as possible
# 470484  Creates a new instance of the New Playlist dia...
# 470485  Report the current cursor location in its window.
#
# [470486 rows x 2 columns]

# %%
test_data.dropna()
test_data
# Out:
#                                                     code  \
# 0      public static String unEscapeString(String str...
# 1      public void checkNextPoissonConsistency(double...
# 2      public DefaultJobRowBuilder(Function<Map<JobFi...
# 3      protected final boolean handleAllocNode(AllocN...
# 4      @Override protected FieldConfigBase createCopy...
# 5      public void handleEntryExpiredSA(EntryExpiredB...
# 6      public static SM_SYSTEM_MESSAGE STR_EXTRACT_GA...
# 7      public void toggle(Animation animIn,Animation ...
# 8      private boolean isInSameEvolutionChain(Pokemon...
# 9      public static SM_SYSTEM_MESSAGE STR_SKILL_SUCC...
# 10     public PhotosGetUploadServerQuery(VkApiClient ...
# 11     public ChangeReport onEquipmentUnitAdd(final E...
# 12     private void requestNewPhotosOrders(Context c,...
# 13     public static void picture(double x,double y,S...
# 14     public VisualTable(Visualization vis,String gr...
# 15     public boolean isCritical(){\n  return false;\...
# 16     public static DataTag buildCreateBasicDataTag(...
# 17     protected void updateRowCount(){\n  int maxrow...
# 18     public boolean isSelected(){\n  ClusterViewer ...
# 19     public int hashCode(){\n  return (int)(Connect...
# 20     protected VideoRemoveTagQuery videoId(int valu...
# 21     public static void cover(String dest,int w,int...
# 22     public Bindings add(String property,JRadioButt...
# 23     public void cancelAlarm(Context context){\n  i...
# 24     public static SM_SYSTEM_MESSAGE STR_SKILL_SUCC...
# 25     public static <T>T findValueOfType(Collection<...
# 26     private static long writeLogSegment(Distribute...
# 27     @Override public void characters(char[] ch,int...
# 28     protected boolean runTestsOnEdt(){\n  return t...
# 29     @Override public Histogram histogram(){\n  ret...
# ...                                                  ...
# 58781  public static String returnWindowsFileAppropri...
# 58782  public synchronized boolean addMacro(int macro...
# 58783  public <T>Future execute(int retries,int inter...
# 58784  public final int yystate(){\n  return zzLexica...
# 58785  protected Expanded doExpand(Record record,long...
# 58786  public void pow(final double a,final double[] ...
# 58787  @PostConstruct public void init(){\n  listener...
# 58788  public static int recordSize(Schema sch){\n  i...
# 58789  public void outputOrigin(){\n  out.println("Af...
# 58790  public static void d(String tag,String msg){\n...
# 58791  public Record verify(List<DataType> values) th...
# 58792  public void showEmpty(Drawable emptyImageDrawa...
# 58793  @Override public void processingInstruction(St...
# 58794  public void goToNextColor(){\n  setColorIndex(...
# 58795  public JSONObject(Object bean){\n  this();\n  ...
# 58796  public static void export(String type,OutputSt...
# 58797  public PhotosGetOwnerPhotoUploadServerQuery ow...
# 58798  public NewsfeedSaveListQuery noReposts(Boolean...
# 58799  public byte[] externalize(){\n  byte[] options...
# 58800  private int parseParameter(String parameter,St...
# 58801  public boolean hasNavigtionBar(){\n  return mH...
# 58802  public static Predicate<ApiFilter> isNonAggreg...
# 58803  public VideoDeleteQuery targetId(Integer value...
# 58804  public AudioSearchQuery(VkApiClient client,Use...
# 58805  public static String base64ToString(final Stri...
# 58806                          public void pause(){\n}\n
# 58807  public Vector process(AudioPreProcessor in) th...
# 58808  @Override public DimensionColumnDataChunk[] re...
# 58809  public boolean acceptsParent(@NotNull NlCompon...
# 58810  public boolean contains(ChangeModifiers modifi...
#
#                                                       nl
# 0      Unescape <code>charToEscape</code> in the stri...
# 1      Verifies that nextPoisson(mean) generates an e...
# 2      Builds a factory for generating JobRows with a...
# 3      Propagates new points-to information of node s...
# 4                           Creates a copy of the field.
# 5                          Handles EntryExpired packets.
# 6                                  You have gathered %0.
# 7                 Toggle the badge visibility in the UI.
# 8      Check if two pokemon are in the same complete ...
# 9                           You stop using [%SkillName].
# 10     Creates a AbstractQueryBuilder instance that c...
# 11       Updates the DAQ by injecting new Equipment Unit
# 12                                           <br> utils.
# 13     Draws the specified image centered at (<em>x</...
# 14      Create a new VisualTable without a parent table.
# 15     is this a critical command that can only be ex...
# 16     Expected generated id is 100. Expected parent ...
# 17     Internal method that updates the row counts fo...
# 18                           this is currently selected?
# 19            Returns a hash code value for this object.
# 20                                             Video ID.
# 21                        make a Cover by source images.
# 22                                  Handles JRadioButton
# 23                                    Cancels the alarm.
# 24     [%SkillCaster] dispelled its magical buffs by ...
# 25     Find a value of one of the given types in the ...
# 26     Write <code>numRecords</code> records to the l...
# 27     PathElement is the only element having values ...
# 28                    Override to run tests off the EDT.
# 29     Returns the histogram that approximates the jo...
# ...                                                  ...
# 58781  There are a couple of characters that Windows ...
# 58782                       Add macro to the collection.
# 58783  Execute the task with N retries, and an interv...
# 58784                 Returns the current lexical state.
# 58785  This method creates pending compactions if the...
# 58786  Compute power of a double to a derivative stru...
# 58787                           Registers to tag caches.
# 58788  Returns the number of bytes required to store ...
# 58789                             for testing and debug.
# 58790                                          debug log
# 58791  Verifies that a list of DataTypes corresponds ...
# 58792    Show empty view when there are not data to show
# 58793  A processing instruction. Processing instructi...
# 58794  Proceed to the next available ring color. This...
# 58795  Construct a JSONObject from an Object using be...
# 58796  Export the provided JasperPrint the format giv...
# 58797  Identifier of a community or current user. <p>...
# 58798    Reposts display on and off ("true" is for off).
# 58799     Converts a linked options list to a byte array
# 58800  Parses the String representation of an integer...
# 58801     Does this device have a system navigation bar?
# 58802  Validity rules for non-aggregatable dimensions...
# 58803                                      Set target id
# 58804  Creates a AbstractQueryBuilder instance that c...
# 58805          Converts Base64 string to a plain string.
# 58806                            Pauses the audio output
# 58807  Performs the transformation of the input data ...
# 58808  Below method will be used to read the chunk ba...
# 58809  Returns whether the given component accepts th...
# 58810           Checks if the specified modifier is set.
#
# [58811 rows x 2 columns]

# %%
# Make data a np.array
train = train_data.values
test = test_data.values

# %%
# Build X and y
y_train = train[:, 1:]
X_train = train[:, 0]
y_test = test[:, 1:]
X_test = test[:, 0]

# %%
X_train
# Out:
# array(['protected void tearDown(){\n}\n',
#        '@KnownFailure("Fixed on DonutBurger, Wrong Exception thrown") public void test_unwrap_ByteBuffer$ByteBuffer_02(){\n  String host="new host";\n  int port=8080;\n  ByteBuffer bbs=ByteBuffer.allocate(10);\n  ByteBuffer bbR=ByteBuffer.allocate(100).asReadOnlyBuffer();\n  ByteBuffer[] bbA={bbR,ByteBuffer.allocate(10),ByteBuffer.allocate(100)};\n  SSLEngine sse=getEngine(host,port);\n  sse.setUseClientMode(true);\n  try {\n    sse.unwrap(bbs,bbA);\n    fail("ReadOnlyBufferException wasn\'t thrown");\n  }\n catch (  ReadOnlyBufferException iobe) {\n  }\ncatch (  Exception e) {\n    fail(e + " was thrown instead of ReadOnlyBufferException");\n  }\n}\n',
#        'public static CstFloat make(int bits){\n  return new CstFloat(bits);\n}\n',
#        ...,
#        'public Optional<Boolean> eagerCheck(){\n  return Optional.ofNullable(this.eagerCheck);\n}\n',
#        'public static NewPlaylistFragment newInstance(Song song){\n  NewPlaylistFragment fragment=new NewPlaylistFragment();\n  Bundle bundle=new Bundle();\n  bundle.putParcelable(KEY_SONG,song);\n  fragment.setArguments(bundle);\n  return fragment;\n}\n',
#        '@DSSink({DSSinkKind.LOG}) @DSGenerator(tool_name="Doppelganger",tool_version="2.0",generated_on="2013-12-30 12:29:19.771 -0500",hash_original_method="06AF2B97EC9C8BBE1303A237FE727449",hash_generated_method="103A7E1B02C228D1981B721CBC7DAC4C") public void updateCursor(View view,int left,int top,int right,int bottom){\n  checkFocus();\nsynchronized (mH) {\n    if ((mServedView != view && (mServedView == null || !mServedView.checkInputConnectionProxy(view))) || mCurrentTextBoxAttribute == null || mCurMethod == null) {\n      return;\n    }\n    mTmpCursorRect.set(left,top,right,bottom);\n    if (!mCursorRect.equals(mTmpCursorRect)) {\n      if (DEBUG)       Log.d(TAG,"updateCursor");\n      try {\n        if (DEBUG)         Log.v(TAG,"CURSOR CHANGE: " + mCurMethod);\n        mCurMethod.updateCursor(mTmpCursorRect);\n        mCursorRect.set(mTmpCursorRect);\n      }\n catch (      RemoteException e) {\n        Log.w(TAG,"IME died: " + mCurId,e);\n      }\n    }\n  }\n}\n'], dtype=object)

# %%
y_train
# Out:
# array([[ 'Tears down the fixture, for example, close a network connection. This method is called after a test is executed.'],
#        [ 'javax.net.ssl.SSLEngine#unwrap(ByteBuffer src, ByteBuffer[] dsts) ReadOnlyBufferException should be thrown.'],
#        [ 'Makes an instance for the given value. This may (but does not necessarily) return an already-allocated instance.'],
#        ...,
#        ['whether check errors as more as possible'],
#        [ 'Creates a new instance of the New Playlist dialog fragment to create a new playlist and add a song to it.'],
#        ['Report the current cursor location in its window.']], dtype=object)

# %%
x = X_train
for i in x:
    i = i.lower()
    
y = y_train[0]
for i in y:
    i = i.lower()
    
xt = X_test
for i in x:
    i = i.lower()
    
yt = y_test[0]
for i in y:
    i = i.lower()

# %%
# for i in range(0, len(X_train)):
#     sumChars = sumChars+X_train[i]+y_train[i][0]

# %%
data = np.concatenate((X_train,y_train[:,0]),axis=0)
data_test = np.concatenate((X_test,y_test[:,0]),axis=0)
vocabs = sorted(list(set(np.concatenate((data,data_test),axis=0))))
vocab_to_int = dict((c, i) for i, c in enumerate(vocabs))   #Vectorize the text
int_to_vocab = dict((i, c) for i, c in enumerate(vocabs))

# %%
vocabs
# Out:
# [' never called.',
#  ' use method without activityactivity parameter is ignored',
#  '!!! Do not remove this code !!! Otherwise it will be impossible to override schedule method',
#  '!!! Warning !!! Code using this class should close the camera device by closing the provided lifetime instead of calling close directly on the camera object. Failing to do so may leave the multi camera lifecycle in an inconsistent state. Returns a future to an API2 Camera device. The future will only complete if the camera is fully opened successfully. If the device cannot be opened, the future will be canceled or provided with an exception depending on the nature of the internal failure. This call will not block the calling thread.',
#  '!!! Warning !!! Code using this class should close the camera device by closing the provided lifetime instead of calling close directly on the camera object. Failing to do so may leave the multi camera lifecycle in an inconsistent state. This returns a future to a CameraProxy device in auto mode and does not make any guarantees about the backing API version. The future will only return if the device is fully opened successfully. If the device cannot be opened, the future will be canceled or provided with an exception depending on the nature of the internal failure. This call will not block the calling thread.',
#  '!!! Warning !!! Code using this class should close the camera device by closing the provided lifetime instead of calling close directly on the camera object. Failing to do so may leave the multi camera lifecycle in an inconsistent state. This returns a future to a CameraProxy device opened explicitly with an API2 backing device. The future will only return if the device is fully opened successfully. If the device cannot be opened, the future will be canceled or provided with an exception depending on the nature of the internal failure. This call will not block the calling thread.',
#  '!!! Warning !!! Code using this class should close the camera device by closing the provided lifetime instead of calling close directly on the camera object. Failing to do so may leave the multi camera lifecycle in an inconsistent state. This returns a future to a CameraProxy device opened explicitly with an legacy backing API. The future will only return if the device is fully opened successfully. If the device cannot be opened, the future will be canceled or provided with an exception depending on the nature of the internal failure. This call will not block the calling thread.',
#  '!!! Warning !!! Code using this class should close the camera device by closing the provided lifetime instead of calling close directly on the camera object. Failing to do so may leave the multi camera lifecycle in an inconsistent state. This returns a future to a legacy Camera device The future will only return if the device is fully opened successfully. If the device cannot be opened, the future will be canceled or provided with an exception depending on the nature of the internal failure. This call will not block the calling thread.',
#  '!!! all methods that use this method must be sync check if value is valid to insert to array (to a multidimesnional array only array with one smaller dimension can be inserted)',
#  '!!! all methods that use this method must be sync check if value is valid to insert to array (to a multidimesnional array only array with one smaller dimension can be inserted), if value is invalid return null;',
#  '!!! all methods that use this method must be sync enlarge the inner array to given size',
#  '!!! all methods that use this method must be sync enlarge the offset if 0',
#  '!!! not used currently, but might be by getPixelbounds?',
#  '!!!! ASSUMPTION: all VAR exists in HTTP Header must of type: APIVARREPLACE_NAME_PREFIX_HTTP_HEADER 20140310 This may be costly (O(n^2)) of the updated related # of headers; # of parameters in the requests. Better to only do it when there are some replacement in the request Parameters. a prefix : TOBE tested',
#  '!!note!! the construct function must be non-public to make sure that this should be created by ResultStat Example:ResultStat.OK.wrap(data, msg)',
#  '!hack! bind instead of release when constructing queries',
#  '""" Apply each rule of this ``RegexpChunkParser`` to ``chunkstr``, in turn. :param chunkstr: The chunk string to which each rule should be applied. :type chunkstr: ChunkString :rtype: None """',
#  '""" Apply the given transformation to the string encoding of this ``ChunkString``.  In particular, find all occurrences that match ``regexp``, and replace them using ``repl`` (as done by ``re.sub``). This transformation should only add and remove braces; it should *not* modify the sequence of angle-bracket delimited tags.  Furthermore, this transformation may not result in improper bracketing.  Note, in particular, that bracketing may not be nested.',
#  '""" Construct a new ``ChunkString`` that encodes the chunking of the text ``tagged_tokens``.',
#  '""" Construct a new ``SplitRule``. :type right_tag_pattern: str :param right_tag_pattern: This rule\'s right tag pattern.  When applied to a ``ChunkString``, this rule will find any chunk containing a substring that matches ``left_tag_pattern`` followed by this pattern.  It will then split the chunk into two new chunks at the point between these two matching patterns. :type left_tag_pattern: str :param left_tag_pattern: This rule\'s left tag pattern.  When applied to a ``ChunkString``, this rule will find any chunk containing a substring that matches this pattern followed by ``right_tag_pattern``.  It will then split the chunk into two new chunks at the point between these two matching patterns. :type descr: str :param descr: A short description of the purpose and/or effect of this rule. """',
#  '""" This function replaces any sequence of non letters and non numbers with a single white space. """',
#  '"""Find longest matching block in a[alo:ahi] and b[blo:bhi]. If isjunk is not defined: Return (i,j,k) such that a[i:i+k] is equal to b[j:j+k], where alo <= i <= i+k <= ahi blo <= j <= j+k <= bhi and for all (i\',j\',k\') meeting those conditions, k >= k\' i <= i\' and if i == i\', j <= j\' In other words, of all maximal matching blocks, return one that starts earliest in a, and of all those maximal matching blocks that start earliest in a, return the one that starts earliest in b. >>> s = SequenceMatcher(None, " abcd", "abcd abcd") >>> s.find_longest_match(0, 5, 0, 9) Match(a=0, b=4, size=5) If isjunk is defined, first the longest matching block is determined as above, but with the additional restriction that no junk element appears in the block.  Then that block is extended as far as possible by matching (only) junk elements on both sides.  So the resulting block never matches on junk except as identical junk happens to be adjacent to an "interesting" match. Here\'s the same example as before, but considering blanks to be junk.  That prevents " abcd" from matching the " abcd" at the tail end of the second sequence directly.  Instead only the "abcd" can match, and matches the leftmost "abcd" in the second sequence: >>> s = SequenceMatcher(lambda x: x==" ", " abcd", "abcd abcd") >>> s.find_longest_match(0, 5, 0, 9) Match(a=1, b=0, size=4) If no blocks match, return (alo, blo, 0). >>> s = SequenceMatcher(None, "ab", "c") >>> s.find_longest_match(0, 2, 0, 1) Match(a=0, b=0, size=0) """',
#  '"""Find the single best match above a score in a list of choices. This is a convenience method which returns the single best choice. See extract() for the full arguments list. Args: query: A string to match against choices: A list or dictionary of choices, suitable for use with extract(). processor: Optional function for transforming choices before matching. See extract(). scorer: Scoring function for extract(). score_cutoff: Optional argument for score threshold. If the best match is found, but it is not greater than this number, then return None anyway ("not a good enough match").  Defaults to 0. Returns: A tuple containing a single match and its score, if a match was found that was above score_cutoff. Otherwise, returns None. """',
#  '"""Get a list of the best matches to a collection of choices. Convenience function for getting the choices with best scores. Args: query: A string to match against choices: A list or dictionary of choices, suitable for use with extract(). processor: Optional function for transforming choices before matching. See extract(). scorer: Scoring function for extract(). score_cutoff: Optional argument for score threshold. No matches with a score less than this number will be returned. Defaults to 0. limit: Optional maximum for the number of elements returned. Defaults to 5. Returns: A a list of (match, score) tuples. """',
#  '"""Process string by -- removing all but letters and numbers -- trim whitespace -- force to lower case if force_ascii == True, force convert to ascii"""',
#  '"""Return a cleaned string with token sorted."""',
#  '"""Return a measure of the sequences\' similarity (float in [0,1]). Where T is the total number of elements in both sequences, and M is the number of matches, this is 2.0*M / T. Note that this is 1 if the sequences are identical, and 0 if they have nothing in common. .ratio() is expensive to compute if you haven\'t already computed .get_matching_blocks() or .get_opcodes(), in which case you may want to try .quick_ratio() or .real_quick_ratio() first to get an upper bound. >>> s = SequenceMatcher(None, "abcd", "bcde") >>> s.ratio() 0.75 >>> s.quick_ratio() 0.75 >>> s.real_quick_ratio() 1.0 """',
#  '"""Return a measure of the sequences\' similarity between 0 and 100 but sorting the token before comparing. """',
#  '"""Return a measure of the sequences\' similarity between 0 and 100, using different algorithms. """',
#  '"""Return the ratio of the most similar substring as a number between 0 and 100 but sorting the token before comparing. """',
#  '"""Select the best match in a list or dictionary of choices. Find best matches in a list or dictionary of choices, return a list of tuples containing the match and it\'s score. If a dictionery is used, also returns the key for each match. Arguments: query: An object representing the thing we want to find. choices: An iterable or dictionary-like object containing choices to be matched against the query. Dictionary arguments of {key: value} pairs will attempt to match the query against each value. processor: Optional function of the form f(a) -> b, where a is an individual choice and b is the choice to be used in matching. This can be used to match against, say, the first element of a list: lambda x: x[0] Defaults to fuzzywuzzy.utils.full_process(). scorer: Optional function for scoring matches between the query and an individual processed choice. This should be a function of the form f(query, choice) -> int. By default, fuzz.WRatio() is used and expects both query and choice to be strings. limit: Optional maximum for the number of elements returned. Defaults to 5. Returns: List of tuples containing the match and its score. If a list is used for choices, then the result will be 2-tuples. If a dictionery is used, then the result will be 3-tuples containing he key for each match. For example, searching for \'bird\' in the dictionary {\'bard\': \'train\', \'dog\': \'man\'} may return [(\'train\', 22, \'bard\'), (\'man\', 0, \'dog\')] """',
#  '"""This convenience function takes a list of strings containing duplicates and uses fuzzy matching to identify  and remove duplicates. Specifically, it uses the process.extract to identify duplicates that  score greater than a user defined threshold. Then, it looks for the longest item in the duplicate list since we assume this item contains the most entity information and returns that. It breaks string  length ties on an alphabetical sort. Note: as the threshold DECREASES the number of duplicates that are found INCREASES. This means that the  returned deduplicated list will likely be shorter. Raise the threshold for fuzzy_dedupe to be less  sensitive. Args: contains_dupes: A list of strings that we would like to dedupe. threshold: the numerical value (0,100) point at which we expect to find duplicates.  Defaults to 70 out of 100 scorer: Optional function for scoring matches between the query and an individual processed choice. This should be a function of the form f(query, choice) -> int. By default, fuzz.token_set_ratio() is used and expects both query and choice to be strings. Returns: A deduplicated list. For example: In: contains_dupes = [\'Frodo Baggin\', \'Frodo Baggins\', \'F. Baggins\', \'Samwise G.\', \'Gandalf\', \'Bilbo Baggins\'] In: fuzzy_dedupe(contains_dupes) Out: [\'Frodo Baggins\', \'Samwise G.\', \'Bilbo Baggins\', \'Gandalf\'] """',
#  '"$fieldInit" - retrieve the internal symbol table entry for the symbol "$fieldInit"',
#  '"$implements" - retrieve the internal symbol table entry for the symbol "$implements"',
#  '"$instanceof" - retrieve the internal symbol table entry for the symbol "$instanceof"',
#  '"$makeClass" - retrieve the internal symbol table entry for the symbol "$makeClass"',
#  '"$makeEnum" - retrieve the internal symbol table entry for the symbol "$makeEnum"',
#  '"$makeInterface" - retrieve the internal symbol table entry for the symbol "$makeInterface"',
#  '"$methods" - retrieve the internal symbol table entry for the symbol "$methods"',
#  '"$n4Export" - retrieve the internal symbol table entry for the symbol "$n4Export"',
#  '"$n4promisifyFunction" - retrieve the internal symbol table entry for the symbol "$n4promisifyFunction"',
#  '"$n4promisifyMethod" - retrieve the internal symbol table entry for the symbol "$n4promisifyMethod"',
#  '"$sliceToArrayForDestruct" - retrieve the internal symbol table entry for the symbol "$sliceToArrayForDestruct"',
#  '"$spawn" - retrieve the internal symbol table entry for the symbol "$spawn"',
#  '"(s)" -> "s", others unchanged',
#  '"/.." at the beginning should be removed as browsers do (not in RFC)',
#  '"/.." at the beginning should be removed as browsers do (not in RFC).',
#  '"1" - return extra information about users and communities',
#  '"1" - return likes info',
#  '"1" - to return complete information about a user\'s communities "0" - to return a list of community IDs without any additional fields (default)',
#  '"1. aaa" --> " 1. aaa" change nested number "1. aaa" --> "12. aaa" change list number',
#  '"1:NUMBER ex:IDENT" -> "1ex:DIMENSION" is a common source source of a-idempotency, but not one that causes problems in practice. This hack helps ignore it.',
#  '"2" -&gt; (0,2)<br/> "1:2" -&gt; (1,2)<br/> "1:" -&gt; (1,0)<br/> "-1:" -&gt; (-1,0)<br/> ":-1" -&gt; (0,-1)<br/> ":" -&gt; (0,0)<br/>',
#  '"2014-01-16 18:59:00" => "2014-01-16"',
#  '"A [noun]" or "An [noun]", depending on the first syllable.',
#  '"ASK" query with an empty KB and CONNEG for various known/accepted MIME Types.',
#  '"ASK" query with an empty KB.',
#  '"Allocates" a node address when we will buffer the nodes in RAM.',
#  '"Array" - retrieve the internal symbol table entry for the symbol "Array"',
#  '"Available and required for advertising agencies." ID of the client ads are retrieved from.',
#  '"Boxes" a double value as either Double or Long depending on the integer flag.',
#  '"C+A+B" -&gt; ["C","A","B"]',
#  '"CSI P_m h" for set or "CSI P_m l" for reset ANSI mode.',
#  '"Called when the screen is unloaded. Used to disable keyboard repeat events."',
#  '"Cancels" this reply processor by instructing the thread that is waiting for replies that it shouldn\'t wait any more.',
#  '"Crawls" the deployment archive and generates the <code>fileList</code> parameter value.',
#  '"Cursors" the specified Coords.',
#  '"Double-quotes" the argument.',
#  '"Factory" method; will create a new child instance of this symbol table. It will be a copy-on-write instance, ie. it will only use read-only copy of parent\'s data, but when changes are needed, a copy will be created. <p> Note: while this method is synchronized, it is generally not safe to both use makeChild/mergeChild, AND to use instance actively. Instead, a separate \'root\' instance should be used on which only makeChild/mergeChild are called, but instance itself is not used as a symbol table.',
#  '"Fake writes" a packet to the client, only running the OnSend event of the packet.',
#  '"Fixes" the given package name. (used to parse the version-tag)',
#  '"For advertising agencies". ID of the client advertising campaigns are retrieved from.',
#  '"For advertising agencies." ID of the client ads are retrieved from.',
#  '"Format" a string by doing a simple key lookup.',
#  '"Generate" new cluster points. Static generators always return their predefined set of points.',
#  '"Has" or "Have", depending on the quantity.',
#  '"Hide" conversation scope by replacing its default "cid" parameter name by something unpredictable.',
#  '"Induced" means that all new demand comes out of nowhere',
#  '"Is" or "Are", depending on the quantity.',
#  '"It" or "Them", depending on the quantity.',
#  '"It" or "They", depending on the quantity.',
#  '"Launch" builds  when the build is in a launching state. This is because in PROD we pre-launch things into singularity and they wait for state changes. In tests this doesn\'t happen so we have to call #launchBuild() ourselves.',
#  '"Mark" document to be a part of subcollection',
#  '"Marks" the last added test for running.  If any tests in the suite is marked, then only the marked tests are run.  Marking allows developers to flag a single test during development and may be useful for debugging or simplying focusing on a perticular (set of) test(s).',
#  '"Mini" SolrCloud cluster to be used for testing',
#  '"Mixed" means that half of the new demand comes from another mode, and the other half comes out of nowhere',
#  '"ModeSwitch" means that all new demand comes from some other mode',
#  '"N4Accessor" - retrieve the internal symbol table entry for the symbol "N4Accessor"',
#  '"N4Annotation" - retrieve the internal symbol table entry for the symbol "N4Annotation"',
#  '"N4ApiNotImplementedError" - retrieve the internal symbol table entry for the symbol "N4ApiNotImplementedError"',
#  '"N4Class" - retrieve the internal symbol table entry for the symbol "N4Class"',
#  '"N4DataField" - retrieve the internal symbol table entry for the symbol "N4DataField"',
#  '"N4EnumType" - retrieve the internal symbol table entry for the symbol "N4EnumType"',
#  '"N4Interface" - retrieve the internal symbol table entry for the symbol "N4Interface"',
#  '"N4Member" - retrieve the internal symbol table entry for the symbol "N4Member"',
#  '"N4Method" - retrieve the internal symbol table entry for the symbol "N4Method"',
#  '"Nillable to string"',
#  '"Not implemented yet" exception.',
#  '"Only for advertising agencies." ID of the client with the advertising account where the group will be created.',
#  '"Pastes" the bytes in the clipboard into the current selection in the hex editor.',
#  '"Permuted term vectors, output by -positionalmethod permutation.',
#  '"Permuted term vectors, output by -positionalmethod permutationplusbasic.',
#  '"Permuted term vectors, output by -positionalmethod proximity.',
#  '"Pivotize" the list, such that all elements before the given position are less than, all elements after the position are larger than the threshold value in the given dimension. (desc inverts the sorting!) Only the elments in the interval <tt>[start: end[</tt> are sorted!',
#  '"Plays back" the last recorded macro in this text area.',
#  '"Refreshes" the transit route by routing between all referenced links of the stop facilities.',
#  '"SMS" text to be sent in "UTF-8" encoding. Only Latin letters and numbers are allowed. Maximum size is "160" characters.',
#  '"Safe save".  Write the string to a backup file, then copy it over the last saved file, and  if everything is OK, delete the originally  written file.',
#  '"Selects" the specified Coords.',
#  '"Semantic inlining" of methods of the Magic class Based on the methodName, generate a sequence of opt instructions that implement the magic, updating the stack as necessary',
#  '"Semantic inlining" of methods of the Magic class. Based on the methodName, generate a sequence of opt instructions that implement the magic, updating the expression stack as necessary.',
#  '"Semantic inlining" of methods of the Magic class. Based on the methodName, generate a sequence of opt instructions that implement the magic, updating the stack as necessary',
#  '"SetAndCount [count=" + count + ", set=" + set + "]";',
#  '"Sets" the current roster entry. Equivalent to the user pressing the "Set" button. Implemented to support xboxThrottle.py',
#  '"Sort" the resources in a list by their status from most important to least important. The idea is to easily identify the resources to be deleted if we are to decrease the resource count',
#  '"Step-Merge" especially useful in Scatter-Gather scenarios. The operator will forward all combinations of the most recent items emitted by each source until any of them completes. Errors will immediately be forwarded. <p> <img class="marble" src="https://raw.githubusercontent.com/reactor/projectreactor.io/master/src/main/static/assets/img/marble/zipp.png" alt=""> <p>',
#  '"Step-Merge" especially useful in Scatter-Gather scenarios. The operator will forward all combinations of the most recent items emitted by each source until any of them completes. Errors will immediately be forwarded. <p> <img class="marble" src="https://raw.githubusercontent.com/reactor/projectreactor.io/master/src/main/static/assets/img/marble/zipt.png" alt=""> <p>',
#  '"Step-Merge" especially useful in Scatter-Gather scenarios. The operator will forward all combinations produced by the passed combinator from the most recent items emitted by each source until any of them completes. Errors will immediately be forwarded. <p> <img class="marble" src="https://raw.githubusercontent.com/reactor/projectreactor.io/master/src/main/static/assets/img/marble/zip.png" alt=""> <p>',
#  '"Step-Merge" especially useful in Scatter-Gather scenarios. The operator will forward all combinations produced by the passed combinator from the most recent items emitted by each source until any of them completes. Errors will immediately be forwarded. <p> <img class="marble" src="https://raw.githubusercontent.com/reactor/projectreactor.io/master/src/main/static/assets/img/marble/zipp.png" alt=""> <p>',
#  '"Step-Merge" especially useful in Scatter-Gather scenarios. The operator will forward all combinations produced by the passed combinator function of the most recent items emitted by each source until any of them completes. Errors will immediately be forwarded. <p> <img class="marble" src="https://raw.githubusercontent.com/reactor/projectreactor.io/master/src/main/static/assets/img/marble/zip.png" alt=""> <p>',
#  '"Step-Merge" especially useful in Scatter-Gather scenarios. The operator will forward all combinations produced by the passed combinator function of the most recent items emitted by each source until any of them completes. Errors will immediately be forwarded. <p> <img class="marble" src="https://raw.githubusercontent.com/reactor/projectreactor.io/master/src/main/static/assets/img/marble/zipp.png" alt=""> <p>',
#  '"String to nillable"',
#  '"System" - retrieve the internal symbol table entry for the symbol "System"',
#  '"Tail-pruning" support for RTFs. This function pops the information previously saved by pushRewindMark (which see) and uses it to discard all nodes added to the DTM after that time. We expect that this will allow us to reuse storage more effectively. This is _not_ intended to be called while a document is still being constructed -- only between endDocument and the next startDocument %REVIEW% WARNING: This is the first use of some of the truncation methods.  If Xalan blows up after this is called, that\'s a likely place to check. %REVIEW% Our original design for DTMs permitted them to share string pools.  If there any risk that this might be happening, we can _not_ rewind and recover the string storage. One solution might to assert that DTMs used for RTFs Must Not take advantage of that feature, but this seems excessively fragile. Another, much less attractive, would be to just let them leak... Nah.',
#  '"Tail-pruning" support for RTFs. This function pushes information about the current size of the DTM\'s data structures onto a stack, for use by popRewindMark() (which see). %REVIEW% I have no idea how to rewind m_elemIndexes. However, RTFs will not be indexed, so I can simply panic if that case arises. Hey, it works...',
#  '"That or "Those", depending on the quantity.',
#  '"The URN consists of a hierarchical service identifier or application identifier, with a sequence of labels separated by periods.The left-most label is the most significant one and is called \'top-level service identifier\', while names to the right are called \'sub-services\' or \'sub-applications\'. For any given service identifier, labels can be removed right-to-left and the resulting URN is still valid, referring a more generic service, with the exception of the top-level service identifier and possibly the first sub-service or sub-application identifier. Labels cannot be removed beyond a defined basic service, for example, the label w.x may define a service, but the label w may only define an assignment authority for assigning subsequent values and not define a service in its own right.  In other words, if a service identifier \'w.x.y.z\' exists, the URNs \'w.x\' and \'w.x.y\' are also valid service identifiers, but w may not be a valid service identifier if it merely defines who is responsible" TODO: PLEASE VALIDATE MY UNDERSTANDING OF THE ABOVE TEXT :)',
#  '"This or "These", depending on the quantity.',
#  '"Unknown" just means that our chunk factory (even when it has been augmented by client code) did not recognize its id',
#  '"Unreads" a character from the stream by placing it in a member variable to be later retreived by readCharFromReader, used by the CSS Parser',
#  '"Use" supplied apple object.  Create an AppleUserThread to stress it out.',
#  '"Visit" the template element, passing the output through a TemplateTransformModel',
#  '"Visit" the template element.',
#  '"Xiaomi" phone is different others,need add AppOpsManager',
#  '"[noun]\'s" or "[noun]\'", depending on the last character.',
#  '"__proto__" - retrieve the internal symbol table entry for the symbol "__proto__"',
#  '"a " or "an ", depending on the noun',
#  '"a [noun]" or "an [noun]", depending on the first syllable.',
#  '"a [noun]" or "an [noun]", depending on the first syllable. Method to prevent collision of items and creatures.',
#  '"active" means that the object is still displayed, and should be stored.',
#  '"arguments" - retrieve the internal symbol table entry for the symbol "arguments"',
#  '"attach image" dispatcher.',
#  '"call" - retrieve the internal symbol table entry for the symbol "call"',
#  '"clones" a new media file.',
#  '"connecting" means "has never been ACTIVE" for both incoming and outgoing calls',
#  '"delsms" cmd deletes sms, either  - all sms  - all sent sms  - sms from specified contact  - #last messages  - #last incoming/outgoing messages',
#  '"expiry time in ms". After that, expiry time is read as a 8 byte unsigned long',
#  '"expiry time in seconds". After that, expiry time is read as a 4 byte unsigned int',
#  '"exports" - retrieve the internal symbol table entry for the symbol "exports"',
#  '"filters" the given population file and exports the filtered population.',
#  '"from" index is excluded.',
#  '"get" - retrieve the internal symbol table entry for the symbol "get"',
#  '"global" - retrieve the internal symbol table entry for the symbol "global"',
#  '"has" or "have", depending on the quantity.',
#  '"http://rapidshare.com&#x2F;&#x66;&#x69;&#x6C;&#x65;&#x73;&#x2F;&#x35;&#x34;&#x35;&#x34;&#x31;&#x34;&#x38;&#x35;&#x2F;&#x63;&#x63;&#x66;&#x32;&#x72;&#x73;&#x64;&#x66;&#x2E;&#x72;&#x61;&#x72;" ; Wandelt alle hexkodierten zeichen in diesem Format in normalen text um',
#  '"id" value returned with a block by the "video.getCatalog" method.',
#  '"id" value returned with a block to hide by the "video.getCatalog" method.',
#  '"is" or "are", depending on the quantity.',
#  '"it" or "them", depending on the quantity.',
#  '"it" or "they", depending on the quantity.',
#  '"level" precedence test - "text/html;level=1" is higher than "text/html"',
#  '"level" precedence test - "text/html;level=2" is higher than "text/html;level=1""',
#  '"lightweight" reduction of the dialogue state (without actual inference).',
#  '"module" - retrieve the internal symbol table entry for the symbol "module"',
#  '"next" value returned with a block by the "video.getCatalog" method.',
#  '"object" - retrieve the internal symbol table entry for the symbol "object"',
#  '"p_j is simply the sum of K- 1 class probabilities, M * K centroid  coordinates, and one variance estimate."',
#  '"prototype" - retrieve the internal symbol table entry for the symbol "prototype"',
#  '"register" - retrieve the internal symbol table entry for the symbol "register"',
#  '"require" - retrieve the internal symbol table entry for the symbol "require"',
#  '"self" - retrieve the internal symbol table entry for the symbol "self"',
#  '"set" - retrieve the internal symbol table entry for the symbol "set"',
#  '"slice" - retrieve the internal symbol table entry for the symbol "slice"',
#  '"square" a way/polygon, based on the algorithm used by iD and before that by P2, originally written by Matt Amos If multiple ways are selected the ways are grouped in groups that share nodes and the groups individually squared.',
#  '"that" or "those", depending on the quantity.',
#  '"this" or "these", depending on the quantity.',
#  '"true" - comments will be returned as numbered objects, in addition lists of "profiles" and "groups" objects will be returned',
#  '"true" - method will return additional fields: likes, can_comment, car_repost, photos. These parameters are not returned by default',
#  '"true" - poll is in a board, "false" - poll is on a wall (by default).',
#  '"true" - to add a star (mark as important) "false" - to remove the star',
#  '"true" - to return outgoing messages "false" - to return incoming messages (default)',
#  '"true" - to return photos only from standard albums "false" - to return all photos including those in service albums, e.g., "My wall photos" (default)',
#  '"typical" multi-valued faceting: not too many unique values, no prefixing. maps to global ordinals as a separate step',
#  '"typical" single-valued faceting: not too many unique values, no prefixing. maps to global ordinals as a separate step',
#  '"typing" - user has started to type.',
#  '"undefined" - retrieve the internal symbol table entry for the symbol "undefined"',
#  '"v is live-in at s."',
#  '"v is live-out at n."',
#  '"v is live-out at s."',
#  '"value" - retrieve the internal symbol table entry for the symbol "value"',
#  '"visit" an IteratorBlock',
#  '# For each element x in b, set b2j[x] to a list of the indices in # b where x appears; the indices are in increasing order; note that # the number of times x appears in b is len(b2j[x]) ... # when self.isjunk is defined, junk elements don\'t show up in this # map at all, which stops the central find_longest_match method # from starting any matching block at a junk element ... # also creates the fast isbjunk function ... # b2j also does not contain entries for "popular" elements, meaning # elements that account for more than 1% of the total elements, and # when the sequence is reasonably large (>= 200 elements); this can # be viewed as an adaptive notion of semi-junk, and yields an enormous # speedup when, e.g., comparing program files with hundreds of # instances of "return NULL;" ... # note that this is only called when b changes; so for cross-product # kinds of matches, it\'s best to call set_seq2 once, then set_seq1 # repeatedly',
#  '# Pushes a pixel in the heap of the given grey value',
#  '# Sorted Token #   find all alphanumeric tokens in the string #   sort those tokens and take ratio of resulting joined strings #   controls for unordered string elements',
#  '# elements in the stack.',
#  '# of edges = # of vertices - 1 No cycles, use dfs to do cycle detection Connected, which means all nodes are visited',
#  '#143 #44 #42 #22: make shure that the filename does not contain illegal chars. This should fix some of the "cannot download" problems.',
#  '#38900 - lazy addition of GUI components',
#  '#<immediate> Case where rotate_imm != 0 Operation: shifter_operand = immed_8 Rotate_Right (rotate_imm * 2) if rotate_imm == 0 then shifter_carry_out = C flag else // rotate_imm != 0 shifter_carry_out = shifter_operand[31]',
#  '#<immediate> Case where rotate_imm == 0 Operation: shifter_operand = immed_8 Rotate_Right (rotate_imm * 2) if rotate_imm == 0 then shifter_carry_out = C flag else // rotate_imm != 0 shifter_carry_out = shifter_operand[31]',
#  '#deprecated use the variant in IOGroovyMethods',
#  '#documentCallsFunction("clCreateBuffer") Create an OpenCL buffer big enough to hold the provided amount of values of the specified type.',
#  '#documentCallsFunction("clCreateBuffer") Create an OpenCL buffer with the provided initial values, in copy mode (see <a href="http://www.khronos.org/registry/cl/sdk/1.0/docs/man/xhtml/clCreateBuffer.html">CL_MEM_COPY_HOST_PTR</a>).',
#  '#documentCallsFunction("clCreateCommandQueue") Create an OpenCL execution queue on this device for the specified context.',
#  '#documentCallsFunction("clCreateContext") Creates an OpenCL context formed of the provided devices.<br> It is generally not a good idea to create a context with more than one device, because much data is shared between all the devices in the same context.',
#  '#documentCallsFunction("clCreateFromGLTexture2D") Creates an OpenCL 2D image object from an OpenGL 2D texture object, or a single face of an OpenGL cubemap texture object.<br> Note that memory objects shared with OpenGL must be acquired / released before / after use from OpenCL.',
#  '#documentCallsFunction("clCreateFromGLTexture3D") Creates an OpenCL 3D image object from an OpenGL 3D texture object<br> Note that memory objects shared with OpenGL must be acquired / released before / after use from OpenCL.',
#  '#documentCallsFunction("clCreateKernel") Find a kernel by its functionName, and optionally bind some arguments to it.',
#  '#documentCallsFunction("clCreateKernelsInProgram") Return all the kernels found in the program.',
#  '#documentCallsFunction("clCreateSubBuffer") Can be used to create a new buffer object (referred to as a sub-buffer object) from an existing buffer object.',
#  '#documentCallsFunction("clEnqueueCopyBuffer") #documentQueue()',
#  '#documentCallsFunction("clEnqueueCopyBuffer") enqueues a command to copy a buffer object identified by src_buffer to another buffer object identified by destination. #documentQueue()',
#  '#documentCallsFunction("clEnqueueFillBuffer") #documentQueue()',
#  '#documentCallsFunction("clEnqueueMapBuffer") #documentQueue() #documentMapFlags()',
#  '#documentCallsFunction("clEnqueueMapBuffer") #documentQueue() #documentMapFlags() #documentEventsToWaitForAndReturn()',
#  '#documentCallsFunction("clEnqueueNDRangeKernel") Enqueues a command to execute a kernel on a device.',
#  '#documentCallsFunction("clEnqueueReadBuffer") #documentQueue()',
#  '#documentCallsFunction("clEnqueueTask") Enqueues a command to execute a kernel on a device. <br> The kernel is executed using a single work-item.',
#  '#documentCallsFunction("clEnqueueUnmapMemObject") #documentQueue()',
#  '#documentCallsFunction("clEnqueueWriteBuffer") #documentQueue()',
#  '#documentCallsFunction("clGetDeviceIDs") List all the devices of the specified types, with only the ones declared as available if onlyAvailable is true.',
#  '#documentCreateImage2D()  #documentRowPitch()',
#  '#documentCreateImage2D()  #documentRowPitch() #documentCopiableImageBuffer()',
#  '#documentCreateImage3D()  #documentRowPitch() #documentSlicePitch()',
#  '#documentCreateImage3D()  #documentRowPitch() #documentSlicePitch() #documentCopiableImageBuffer()',
#  '#documentEventsToWaitForAndPairReturn("byte buffer")',
#  '#documentEventsToWaitForAndPairReturn("mapped data")',
#  '#qqqq a=b b=c',
#  '$x\t\tAttribute: rule arguments, return values, predefined rule prop.',
#  '$x.y\tAttribute: x is surrounding rule, label ref (in any alts)',
#  "$x.y, x can be surrounding rule, token/rule/label ref. y is visible attr in that dictionary.  Can't see args on rule refs.",
#  '%%% Javadoc comments to be added here',
#  '%\'1024n+0..9\' ~%\'1024n+0..9\' n\'10\' ~n\'10..20\' s"getSku" r"get.*" ip"1.2.3/24"',
#  '%0 %1 %2 has died in %3.',
#  '%0 : %1',
#  '%0 Legion lost %1.',
#  '%0 Pats its tummy and indicates that its full.',
#  '%0 Premium Seal Breaking Scrolls have arrived. They will vanish in 60 minutes or if you log out.',
#  '%0 Shouts:',
#  '%0 Whispers:',
#  "%0 blocked %1's attack.",
#  '%0 blocked the attack.',
#  '%0 blocked your attack.',
#  '%0 can only upgrade cubes of level %1 or higher.',
#  '%0 can only upgrade cubes to level %1.',
#  '%0 can only upgrade private warehouses of level %1 or higher.',
#  '%0 can only upgrade warehouses of level %1 or higher.',
#  '%0 can only upgrade warehouses to level %1.',
#  "%0 can't apply to join the selected group as he or she is already a member of an alliance.",
#  '%0 cannot accept your Mini Game invitation right now.',
#  '%0 cannot be combined.',
#  '%0 cannot be discarded.',
#  '%0 cannot be dyed.',
#  '%0 cannot be enchanted any more.',
#  '%0 cannot be enchanted.',
#  '%0 cannot be equipped as its rank exceeds the maximum rank of the Stigma slot.',
#  '%0 cannot be given to others.',
#  '%0 cannot be socketed with Manastone.',
#  '%0 cannot be socketed with manastones.',
#  '%0 cannot be summoned right now.',
#  '%0 cannot be used for modification.',
#  '%0 cannot break the combination.',
#  '%0 cannot eat any food.',
#  '%0 cannot trade at the moment.',
#  '%0 captured the %1 Artifact.',
#  '%0 declined your challenge.',
#  '%0 declined your friend request.',
#  '%0 declined your summoning.',
#  '%0 declined your trade offer.',
#  '%0 defeated %1 in a duel.',
#  "%0 denied %1's request for permission to pick up %2.",
#  "%0 denied %1's request to change the item distribution method.",
#  '%0 denied your request for permission to pick up %1.',
#  '%0 disappeared because your Abyss Rank changed.',
#  '%0 disappears in 1 minute because your Abyss Rank changed.',
#  '%0 disappears in 10 minutes because your Abyss Rank changed.',
#  '%0 distributed %num1 Kinah among %num2 people, giving %num3 Kinah each.',
#  '%0 does not buy items.',
#  '%0 does not have the right to roll the dice.',
#  '%0 does not sell items.',
#  '%0 dropped out of training and left the Empyrean Crucible.',
#  '%0 eats %1.',
#  '%0 ended the pause state of %0.',
#  '%0 ends the voice chatting.',
#  '%0 entrusted %1 with the league leadership authority. From now on, %1 is the league leader.',
#  "%0 evaded %1's attack.",
#  '%0 evaded the attack.',
#  '%0 evaded your attack.',
#  '%0 failed the training and has been sent to the Ready Room.',
#  '%0 failed to craft %1.',
#  '%0 failed to defend %1.',
#  '%0 feels a little better.',
#  '%0 feels a lot better.',
#  '%0 feels much better.',
#  '%0 gave up rolling the dice.',
#  '%0 gave up the Bidding.',
#  '%0 gave you %1.',
#  '%0 gives up the attack.',
#  '%0 gives up the pursuit.',
#  '%0 has acquired %1.',
#  '%0 has already been sold.',
#  '%0 has already requested the item distribution method to be changed.',
#  '%0 has become a Legion Centurion.',
#  '%0 has become a Legion Member.',
#  '%0 has become a Legionary.',
#  '%0 has become the Legion Brigade General.',
#  '%0 has become the Legion Deputy.',
#  '%0 has become the new group leader.',
#  '%0 has been activated.',
#  '%0 has been banned.',
#  '%0 has been conditioned as much as it can be. You cannot condition it to Level %1.',
#  "%0 has been conditioned to level %1, and the item's stats have changed.",
#  '%0 has been conditioned to level %1.',
#  '%0 has been conditioned. You cannot condition it further.',
#  '%0 has been deleted from the Ban List.',
#  '%0 has been demoted to member from vice Captain.',
#  '%0 has been destroyed.',
#  '%0 has been disconnected from the server.',
#  '%0 has been disconnected.',
#  '%0 has been dismissed.',
#  '%0 has been kicked out of the alliance.',
#  '%0 has been kicked out of the arena.',
#  '%0 has been kicked out of the group and thus the alliance.',
#  '%0 has been kicked out of the private channel.',
#  '%0 has been kicked out of your group.',
#  "%0 has been lowered to %1 because you haven't killed the lower level targets for a certain time.",
#  '%0 has been offline for too long and had been automatically kicked out of the alliance.',
#  '%0 has been offline for too long and has been automatically kicked out of the group and the alliance.',
#  '%0 has been offline for too long and is automatically excluded from the group.',
#  '%0 has been sealed by a GM. You cannot remove this seal.',
#  '%0 has been sealed.',
#  '%0 has been sold.',
#  '%0 has blocked all Whispers from characters under level %1.',
#  '%0 has blocked all mail from characters under level %1.',
#  '%0 has blocked you.',
#  '%0 has challenged you to a duel.',
#  '%0 has conquered %1.',
#  '%0 has declined to become the Legion Brigade General.',
#  '%0 has declined your Legion invitation.',
#  '%0 has declined your invitation to join the alliance.',
#  '%0 has declined your invitation to the Mini Fortress Battle.',
#  '%0 has declined your invitation.',
#  '%0 has defeated %1.',
#  '%0 has deleted you from their Friends List.',
#  '%0 has destroyed %1.',
#  '%0 has died.',
#  '%0 has enjoyed eating %1 and looks happy.',
#  '%0 has enjoyed eating %1 and looks pleased.',
#  '%0 has enjoyed eating %1.',
#  '%0 has entered the private channel.',
#  "%0 has expelled %1's alliance from the Alliance League.",
#  '%0 has expelled your alliance from the Alliance League.',
#  '%0 has finished eating %1.',
#  '%0 has given up following because the distance between you is too great.',
#  '%0 has joined the Mini Fortress Battle.',
#  '%0 has joined the alliance.',
#  '%0 has joined your Legion.',
#  '%0 has joined your group.',
#  '%0 has kicked out %1 of the alliance.',
#  '%0 has kicked you out of the alliance.',
#  '%0 has left the Legion.',
#  '%0 has left the alliance due to a prolonged absence.',
#  '%0 has left the alliance.',
#  '%0 has left the battle.',
#  '%0 has left the private channel.',
#  '%0 has left your group.',
#  '%0 has logged in.',
#  '%0 has logged out.',
#  '%0 has lost %num1 XP.',
#  '%0 has promoted %1. From now on, %1 is the alliance captain.',
#  '%0 has reached level %1.',
#  '%0 has received %num1 XP.',
#  '%0 has received a proxy petition generated by the GM. The petition number is %1.',
#  '%0 has received a request from the GM for consultation.',
#  '%0 has reentered the Illusion Stadium.',
#  '%0 has requested to check the combat readiness.',
#  '%0 has sent you a friend request.',
#  '%0 has succeeded in enchanting %1 to Level 15.',
#  '%0 has succeeded in enchanting %1 to Level 20.',
#  '%0 has used level %1 %2.',
#  '%0 has used the Gate Guardian Stone to repair the castle gate by %1.',
#  '%0 has withdrawn the challenge for a duel.',
#  '%0 indicates that it is not hungry.',
#  '%0 inflicted %num2 damage on %1.',
#  '%0 is a member of another Legion.',
#  '%0 is a member of another alliance.',
#  '%0 is able to fly again.',
#  '%0 is already a member of another Alliance League.',
#  '%0 is already a member of another alliance.',
#  '%0 is already a member of another group.',
#  '%0 is already a member of your Legion.',
#  '%0 is already a member of your alliance.',
#  '%0 is already a member of your group.',
#  '%0 is already fighting a duel with another opponent.',
#  '%0 is answering another request and cannot respond.',
#  '%0 is asking for help from %1.',
#  '%0 is at a hard-to-find location.',
#  '%0 is at the position indicated on the map.',
#  '%0 is crafting %1.',
#  '%0 is currently not accepting any Whispers.',
#  '%0 is currently refusing the View Detail access.',
#  '%0 is currently refusing to accept items.',
#  '%0 is currently rejecting Legion invitations.',
#  '%0 is currently rejecting alliance invitations.',
#  '%0 is currently rejecting group invitations.',
#  '%0 is currently rejecting trade requests.',
#  '%0 is currently unable to join a group or a force.',
#  '%0 is gone.',
#  '%0 is grateful and gives you a %1 as a present (Times remaining: %2/%3).',
#  '%0 is grateful and gives you a %1 as a present.',
#  '%0 is in Guard mode.',
#  '%0 is in Resting mode.',
#  '%0 is in Stand-by mode.',
#  '%0 is in the %1 region.',
#  '%0 is is no longer available.',
#  '%0 is located at %1.',
#  '%0 is located at %2 in %1.',
#  '%0 is no longer a Mentor.',
#  '%0 is no longer afraid.',
#  '%0 is no longer bleeding.',
#  '%0 is no longer blinded.',
#  '%0 is no longer bound.',
#  '%0 is no longer confused.',
#  '%0 is no longer diseased.',
#  '%0 is no longer immobilized.',
#  '%0 is no longer paralyzed.',
#  '%0 is no longer poisoned.',
#  '%0 is no longer shocked.',
#  '%0 is no longer silenced.',
#  '%0 is no longer spinning.',
#  '%0 is no longer staggering.',
#  '%0 is no longer stunned.',
#  '%0 is no longer vulnerable.',
#  '%0 is not a combined item.',
#  '%0 is not a member of your Legion.',
#  '%0 is not a sealed item.',
#  '%0 is not a target you can trade %1 with.',
#  '%0 is not a tradable item.',
#  '%0 is not able to enter the Instanced Zone right now.',
#  '%0 is not an appearance-modified item.',
#  '%0 is not an extractable item.',
#  '%0 is not an item that can be sold.',
#  '%0 is not an item you can add ability to.',
#  '%0 is not currently accepting duel requests.',
#  '%0 is not currently accepting friend requests.',
#  '%0 is not playing the game.',
#  '%0 is not socketed with a manastone.',
#  '%0 is now Captain of the alliance.',
#  '%0 is now a Mentor.',
#  '%0 is now pending unsealing. This will take %DURATIONDAY1 days.',
#  '%0 is now pending unsealing. This will take 7 days.',
#  '%0 is now selling rare items.',
#  '%0 is now the alliance captain.',
#  '%0 is now the owner of %1.',
#  '%0 is now vice Captain of the alliance.',
#  '%0 is now vulnerable.',
#  '%0 is one of the quality items waiting to be distributed.',
#  '%0 is open and you can now access %1.',
#  '%0 is participating in another Mini Fortress Battle.',
#  '%0 is released from the Aerial Snare.',
#  "%0 is removed because you haven't killed the lower level targets for a certain time.",
#  '%0 is running away.',
#  '%0 is selling items to extract vitality and Aether.',
#  '%0 is selling materials to create the items of Crafting Masters.',
#  '%0 is selling special materials for Master Crafting.',
#  '%0 is thankful and gives you %2.',
#  '%0 is the new channel leader.',
#  '%0 is under attack.',
#  '%0 is unsealed.',
#  '%0 is where it is indicated on the map, but the path leading to it cannot be found.',
#  '%0 is worn out and useless.',
#  '%0 kicked %1 out of the Legion.',
#  '%0 killed the Guardian General.',
#  '%0 lost the %1 Artifact.',
#  "%0 parried %1's attack.",
#  '%0 parried the attack.',
#  '%0 parried your attack.',
#  '%0 pauses %1 temporarily.',
#  '%0 quit the Mini Fortress Battle, and %1 became the leader.',
#  '%0 recovered from the cursed state.',
#  '%0 recovered from the petrified state.',
#  '%0 resisted your attack.',
#  '%0 restored %num1 HP.',
#  '%0 restored %num1 MP.',
#  '%0 restored his flight time by %num1.',
#  '%0 rolled the dice and got %1 (max. %num2).',
#  '%0 rolled the dice and got a %num1 (max. %num2).',
#  '%0 rolled the dice and got a %num1.',
#  '%0 rolled the highest (%0 rolled %1, while you passed).',
#  '%0 rolled the highest (%0 rolled %1, while you rolled %2).',
#  '%0 seconds remain until you can cast it again.',
#  '%0 settled the account instantly.',
#  '%0 skill (Level %1)',
#  '%0 spaces have been added to your account warehouse.',
#  '%0 spaces have been added to your cube.',
#  '%0 spaces have been added to your personal warehouse.',
#  '%0 spits out %1 and makes a face.',
#  '%0 starts the voice chatting.',
#  '%0 starts to attack the enemy.',
#  '%0 succeeded in conquering %1.',
#  '%0 succeeded in crafting %1.',
#  '%0 successfully crafted %1.',
#  '%0 unearthed a buried %1 for you.',
#  '%0 unpauses %1.',
#  '%0 was automatically entrusted with the league leader authority.',
#  '%0 was changed using [%SkillName].',
# ...
#  '* Test Method from Apache Derby Project Class org.apache.derbyTesting.functionTests.tests.jdbcapi.DatabaseMetaDataTest Takes a result set and an array of expected colum names (as Strings)  and asserts that the column names in the result set metadata match the number, order, and names of those in the array.',
#  '* Test the crawl of a site without robots.txt file',
#  '* The order of the corners is: 0------->1 ^        | |   4    | |        v 3<-------2',
#  '* This method incorporates all certificates passed as parameter.',
#  '* This methods save the photo in memory device with diferents params *',
#  '* Used to create a formatted time string for the duration of tracks.',
#  '* Util methods\t                                                            *',
#  "* Wave's Bodyguard *",
#  '* Western Shield Generator Periodic Spawn  *',
#  '* Writes the parameters contained in the requests parameter map to the given writer.',
#  '* check if the job is hamap or prosite then assign it higher priority',
#  '* convert an uncompressed array of bytes to a string',
#  '* deformatNVP: Function to break up the NVP string into a HashMap pPayLoad is the NVP string. returns a HashMap object containing all the name value pairs of the string. *',
#  '* fifth pass, final damage and threat approximation --prevents moves that from the previous pass would cause the mech to die *',
#  '* finds the determinant of a minor of a 4 x 4 matrix',
#  '* first pass, filter moves based upon present case *',
#  '* fourth pass, speculation on top moves use averaging to filter *',
#  "* install package silent by root <ul> <strong>Attentions:</strong> <li>Don't call this on the ui thread, it may costs some times.</li> <li>You should add <strong>android.permission.INSTALL_PACKAGES</strong> in manifest, so no need to request root permission, if you are system app.</li> </ul>",
#  '* like a merge sort',
#  '* third pass, (not so bad) oppurtunistic planner gives preference to good ranges/defensive positions based upon the mech characterization *',
#  '* write_header()\t\t\t        Function writes out header of output file containing ritz values   *',
#  '** This function is voodoo.** <br/> This is the function which actually calls the builders to produce the wrappers which implement the version of the requested API.',
#  '*** Build Of Class',
#  '*** Capture node and event and add to table',
#  '*** return true if creating or editing',
#  '****** popup AbstractAction method overrides',
#  '****** popup AbstractAction.actionPerformed method overrides',
#  '********* KeyListener of Editor',
#  '********* Mouse',
#  '*********** Responses for Edit Action and Edit Variable Buttons *',
#  '************ Currently only needed for IndicatorTO type',
#  '************* DefaultListSelectionModel overrides',
#  '************* popup AbstractAction.actionPerformed method overrides *',
#  '************** Common methods *********************',
#  '************** DragGestureListener',
#  '************** DragSourceListener',
#  '************** Set up editing Frames',
#  '*************** ABActivityViewer',
#  '*************** IEmojiSelectedListener',
#  '*************** OnRefreshListener',
#  '*************** put',
#  '**************** PRIVATE METHODS',
#  '***************** end button actions',
#  '***************** methods',
#  '****************** outgoing',
#  '******************* Circuitbuilder',
#  '******************* PENDING(): re-enable these when we figure out how to do c:forEach. <p/> // Components Inside Choose (Explicit Identifiers) public void testJstlChoose01() throws Exception { <p/> // Check each individual case multiple times checkJstlChoose00(); checkJstlChoose01a(); checkJstlChoose01a(); checkJstlChoose01a(); checkJstlChoose00(); checkJstlChoose01b(); checkJstlChoose01b(); checkJstlChoose01b(); checkJstlChoose00(); checkJstlChoose01c(); checkJstlChoose01c(); checkJstlChoose01c(); <p/> // Check cases in ascending order checkJstlChoose00(); checkJstlChoose01a(); checkJstlChoose01b(); checkJstlChoose01c(); <p/> // Check cases in descending order checkJstlChoose00(); checkJstlChoose01c(); checkJstlChoose01b(); checkJstlChoose01a(); <p/> // Check cases in random order checkJstlChoose00(); checkJstlChoose01b(); checkJstlChoose01a(); checkJstlChoose01c(); <p/> } <p/> <p/> // Components Inside Choose (In Naming Container) public void testJstlChoose02() throws Exception { <p/> // Check each individual case multiple times checkJstlChoose00(); checkJstlChoose02a(); checkJstlChoose02a(); checkJstlChoose02a(); checkJstlChoose00(); checkJstlChoose02b(); checkJstlChoose02b(); checkJstlChoose02b(); checkJstlChoose00(); checkJstlChoose02c(); checkJstlChoose02c(); checkJstlChoose02c(); <p/> // Check cases in ascending order checkJstlChoose00(); checkJstlChoose02a(); checkJstlChoose02b(); checkJstlChoose02c(); <p/> // Check cases in descending order checkJstlChoose00(); checkJstlChoose02c(); checkJstlChoose02b(); checkJstlChoose02a(); <p/> // Check cases in random order checkJstlChoose00(); checkJstlChoose02b(); checkJstlChoose02a(); checkJstlChoose02c(); <p/> } <p/> <p/> // Form with fields rendered inside a <c:forEach> - pristine public void testJstForEach01_pristine() throws Exception { <p/> checkJstlForEach00(); checkJstlForEach01(getJstlForEach01(), jstlForEach01_pristine); checkJstlForEach00(); checkJstlForEach01(getJstlForEach01(), jstlForEach01_pristine); checkJstlForEach00(); <p/> } <p/> <p/> // Form with fields rendered inside a <c:forEach> - submit unchanged public void testJstForEach01_submit01() throws Exception { <p/> checkJstlForEach00(); HtmlPage page = getJstlForEach01(); checkJstlForEach01(page, jstlForEach01_pristine); HtmlForm form = getFormById(page, jstlForEach01_name); assertNotNull("form exists", form); HtmlSubmitInput submit = (HtmlSubmitInput) form.getInputByName(jstlForEach01_name + NamingContainer.SEPARATOR_CHAR + "submit"); page = (HtmlPage) submit.click(); checkJstlForEach01(page, jstlForEach01_pristine); checkJstlForEach00(); <p/> } <p/> <p/> // Form with fields rendered inside a <c:forEach> - submit modified public void testJstForEach01_submit02() throws Exception { <p/> checkJstlForEach00(); HtmlPage page = getJstlForEach01(); checkJstlForEach01(page, jstlForEach01_pristine); HtmlForm form = getFormById(page, jstlForEach01_name); assertNotNull("form exists", form); for (int i = 0; i < jstlForEach01_names.length; i++) { HtmlTextInput input = (HtmlTextInput) form.getInputByName(jstlForEach01_name + NamingContainer.SEPARATOR_CHAR + jstlForEach01_names[i]); assertNotNull("field \'" + jstlForEach01_names[i] + "\' exists", input); input.setValueAttribute(jstlForEach01_updated[i]); } HtmlSubmitInput submit = (HtmlSubmitInput) form.getInputByName(jstlForEach01_name + NamingContainer.SEPARATOR_CHAR + "submit"); page = (HtmlPage) submit.click(); checkJstlForEach01(page, jstlForEach01_updated); checkJstlForEach00(); <p/> } <p/> <p/> // Components Inside Conditional public void testJstlIf01() throws Exception { <p/> // Check the "true" case multiple times in a row checkJstlIf00(); checkJstlIf01a(); checkJstlIf01a(); checkJstlIf01a(); checkJstlIf01a(); <p/> // Check the "false case multiple times in a row checkJstlIf00(); checkJstlIf01b(); checkJstlIf01b(); checkJstlIf01b(); checkJstlIf01b(); <p/> // Check alternating access to the same page (first pattern) checkJstlIf00(); checkJstlIf01a(); checkJstlIf01 ...
#  '******************** DnD',
#  '********************* Boxing/casts',
#  '********************* InternalFrameListener implementatiom *',
#  '********************* init',
#  '********************* on result',
#  '********************* reflect execute method',
#  '********************* reflect execute result',
#  '********************* request',
#  '********************** Called by CircuitBuilder',
#  '********************** Error Dialogs',
#  '********************** OPTIONS MENU',
#  '********************** implements ModuleProxy',
#  '*********************** Methods for Edit Variable Window *',
#  '*********************** end setup',
#  '************************ SurfaceHolder.Callback Start',
#  '************************* DropTargetListener',
#  '************************* search',
#  '************************** DnD',
#  '************************** select',
#  '************************** static methods',
#  '*************************** WYPORIUM TRADE QUERIES',
#  '**************************** SurfaceHolder.Callback Start',
#  '**************************** end',
#  '***************************** HORN MELODIES QUERIES',
#  '***************************** Life cycle',
#  '***************************** SurfaceHolder Callback',
#  '***************************** life cycle',
#  '***************************** role',
#  '****************************** ARENA QUEST QUERIES',
#  '****************************** ARENA REWARD QUERIES',
#  '****************************** ARMOR QUERIES',
#  '****************************** COMBINING QUERIES',
#  '****************************** COMPONENT QUERIES',
#  '****************************** DECORATION QUERIES',
#  '****************************** GATHERING QUERIES',
#  '****************************** HUNTING REWARD QUERIES',
#  '****************************** ITEM QUERIES',
#  '****************************** ITEM TO MATERIAL QUERIES',
#  '****************************** ITEM TO SKILL TREE QUERIES',
#  '****************************** LOCATION QUERIES',
#  '****************************** MONSTER DAMAGE QUERIES',
#  '****************************** MONSTER QUERIES',
#  '****************************** MONSTER STATUS QUERIES',
#  '****************************** MONSTER TO ARENA QUERIES',
#  '****************************** MONSTER TO QUEST QUERIES',
#  '****************************** MediaPlayer Start',
#  '****************************** PALICO WEAPON QUERIES',
#  '****************************** QUEST QUERIES',
#  '****************************** QUEST REWARD QUERIES',
#  '****************************** SKILL QUERIES',
#  '****************************** SKILL TREE QUERIES',
#  '****************************** WEAPON QUERIES',
#  '****************************** WEAPON TREE QUERIES',
#  '****************************** WISHLIST COMPONENT QUERIES',
#  '****************************** WISHLIST DATA QUERIES',
#  '****************************** WISHLIST QUERIES',
#  '******************************* Event',
#  '******************************* decode resource',
#  '**************************************** list support',
#  '***************************************** A simple routine that opens a key ring file and loads the first available key suitable for encryption.',
#  '*************************************************** Camera Start',
#  '****************************************************** DEBUG UTILITIES',
#  '****************************************************** MAIN ALGORITHM: CORE',
#  '****************************************************** MAIN ALGORITHM: INITIALIZATION *',
#  '****************************************************** SEARCH INTERFACE',
#  '****************************************************** STATISTICAL TESTS',
#  '******************************************************************************** /* Private / <p> <p> /** creates OrderedNodePairs out of given List. For use in consistent and applyTo',
#  '*********************************************************************************** Checks if given string represents a valid hex encoded 64-bit long key id.',
#  '*********************************************************************************** Checks if given string represents a valid hex encoded V4 fingerprint.',
#  '*********************************************************************************** Checks if given string represents a valid key id whether it is a short key id, long key id, or a fingerprint.',
#  '*********************************************************************************** Delete entry in the Keystore',
#  '*********************************************************************************** Export Certificate',
#  '*********************************************************************************** Exports given public key as ASCII armored text.',
#  '*********************************************************************************** Generate x509 Certificate',
#  '*********************************************************************************** Hex encode given numeric key id as a short key id.',
#  '*********************************************************************************** Hex encode given numeric key id.',
#  '*********************************************************************************** Import Certificate(HEX) into Keystore',
#  '*********************************************************************************** Load keystore and create KeyStore object',
#  '*********************************************************************************** Save changes in the keystore',
#  '**************Boring accounting for zero graphs***********',
#  '*BEAST block, write the species, species tree, species tree model, likelihood, etc.',
#  '*Internal API, used only between nodes <p> Get backup file name',
#  '*Internal API, used only between nodes <p> Wake up node',
#  '*Internal API, used only between nodes Send backup file name to a node',
#  '*Optional Add a new row to the keyboard',
#  "*Optional Requests clients to hide the keyboard as soon as it's been used. Defaults to false",
#  "*Optional Requests clients to resize the keyboard vertically for optimal fit (e.g., make the keyboard smaller if there are just two rows of buttons). Defaults to false, in which case the custom keyboard is always of the same height as the app's standard keyboard",
#  '*Optional Sets a short description of the result to be shown in the inline result selection pane',
#  '*Optional Sets the Foursquare ID for the venue',
#  '*Optional Sets the HTTP url to be opened when button is pressed',
#  '*Optional Sets the ID of the message you want to reply to',
#  '*Optional Sets the ID to the provided value. If none is set a random 32 char long ID will be generated.',
#  '*Optional Sets the Message object that you want to reply to',
#  '*Optional Sets the ParseMode for the message to the provided value. Defaults to NONE if not set',
#  '*Optional Sets the ParseMode that you want to use for this message',
#  '*Optional Sets the ReplyMarkup that you want to send with the message',
#  '*Optional Sets the URL of the result',
#  '*Optional Sets the URL of the thumbnail that should show next to the result in the inline result selection pane',
#  '*Optional Sets the cache time for this response in seconds. If not set this will default to 300 seconds',
#  '*Optional Sets the caption that you want to send with the Message',
#  '*Optional Sets the caption to be sent with the message',
#  '*Optional Sets the caption to the provided value. This can be 0-200 characters in length',
#  '*Optional Sets the caption you want to send with the message',
#  '*Optional Sets the caption you wat to be sent with this result to the provided String',
#  '*Optional Sets the content you want to be sent with this result to the provided InputMessageContent object',
#  '*Optional Sets the data to be sent in a callback query to the bot when button is pressed, 1-64 bytes',
#  '*Optional Sets the description to the provided value',
#  '*Optional Sets the descrption to the provided value',
#  '*Optional Sets the duration of the audio file to be sent',
#  '*Optional Sets the duration of the audio to the provided value',
#  '*Optional Sets the duration of the video file being sent for this result',
#  '*Optional Sets the duration of the video file to be sent',
#  '*Optional Sets the duration of the voice recording file being sent for this result',
#  '*Optional Sets the duration of the voice recording file to be sent',
#  '*Optional Sets the foursquare ID for the venue to be sent',
#  '*Optional Sets the foursquare ID of the venue to the provided value',
#  '*Optional Sets the height of the gif for the result',
#  '*Optional Sets the height of the mpeg4gif for the result',
#  '*Optional Sets the height of the photo for the result',
#  '*Optional Sets the height of the video file being sent for this result',
#  ...]

# %%
# X = np.zeros((len(data)/SEQ_LENGTH, SEQ_LENGTH, VOCAB_SIZE))
# y = np.zeros((len(data)/SEQ_LENGTH, SEQ_LENGTH, VOCAB_SIZE))
# for i in range(0, len(data)/SEQ_LENGTH):
#     X_sequence = data[i*SEQ_LENGTH:(i+1)*SEQ_LENGTH]
#     X_sequence_ix = [char_to_ix[value] for value in X_sequence]
#     input_sequence = np.zeros((SEQ_LENGTH, VOCAB_SIZE))
#     for j in range(SEQ_LENGTH):
#         input_sequence[j][X_sequence_ix[j]] = 1.
#     X[i] = input_sequence

#     y_sequence = data[i*SEQ_LENGTH+1:(i+1)*SEQ_LENGTH+1]
#     y_sequence_ix = [char_to_ix[value] for value in y_sequence]
#     target_sequence = np.zeros((SEQ_LENGTH, VOCAB_SIZE))
#     for j in range(SEQ_LENGTH):
#         target_sequence[j][y_sequence_ix[j]] = 1.
#     y[i] = target_sequence

# %%
encoded = np.array([vocab_to_int[c] for c in data], dtype=np.int32)

# %%
encoded.shape
# Out:
# (940972,)

# %%
Xencoded = encoded[0:470486]
Yencoded = encoded[470486:940972]

# %%
Xencoded = np.reshape(Xencoded, (-1,1))

# %%
encodedt = np.array([vocab_to_int[c] for c in data_test], dtype=np.int32)

# %%
XTencoded = encoded[0:20]
YTencoded = encoded[20:encodedt.shape[0]]

# %%
XTencoded = np.reshape(XTencoded, (-1,1))

# %%
# Xencoded = np.array([Xencoded]).transpose()
# Xtest[:,0] = Xencoded

# %%
# Import Tensorflow
import tensorflow as tf
# Out:
# /anaconda3/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: compiletime version 3.6 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.5
#   return f(*args, **kwds)

# %%
# Number of pieces of data in training
n_code = Xencoded.shape[1]

# Neurons
n_neurons_1 = 1024
n_neurons_2 = 512
n_neurons_3 = 256
n_neurons_4 = 128

# %%
# Session
net = tf.InteractiveSession()

# %%
# Placeholder
X = tf.placeholder(dtype=tf.float32, shape=[None, n_code])
Y = tf.placeholder(dtype=tf.float32, shape=[None])

# %%
# Initializers
sigma = 1
weight_initializer = tf.variance_scaling_initializer(mode="fan_avg", distribution="uniform", scale=sigma)
bias_initializer = tf.zeros_initializer()

# %%
# Hidden weights
W_hidden_1 = tf.Variable(weight_initializer([n_code, n_neurons_1]))
bias_hidden_1 = tf.Variable(bias_initializer([n_neurons_1]))
W_hidden_2 = tf.Variable(weight_initializer([n_neurons_1, n_neurons_2]))
bias_hidden_2 = tf.Variable(bias_initializer([n_neurons_2]))
W_hidden_3 = tf.Variable(weight_initializer([n_neurons_2, n_neurons_3]))
bias_hidden_3 = tf.Variable(bias_initializer([n_neurons_3]))
W_hidden_4 = tf.Variable(weight_initializer([n_neurons_3, n_neurons_4]))
bias_hidden_4 = tf.Variable(bias_initializer([n_neurons_4]))

# %%
# Output weights
W_out = tf.Variable(weight_initializer([n_neurons_4, 1]))
bias_out = tf.Variable(bias_initializer([1]))

# %%
# Hidden layer
hidden_1 = tf.nn.relu(tf.add(tf.matmul(X, W_hidden_1), bias_hidden_1))
hidden_2 = tf.nn.relu(tf.add(tf.matmul(hidden_1, W_hidden_2), bias_hidden_2))
hidden_3 = tf.nn.relu(tf.add(tf.matmul(hidden_2, W_hidden_3), bias_hidden_3))
hidden_4 = tf.nn.relu(tf.add(tf.matmul(hidden_3, W_hidden_4), bias_hidden_4))

# %%
# Output layer (transpose!)
out = tf.transpose(tf.add(tf.matmul(hidden_4, W_out), bias_out))

# %%
# Cost function
mse = tf.reduce_mean(tf.squared_difference(out, Y))

# %%
# Optimizer
# Adam
opt = tf.train.AdamOptimizer().minimize(mse)

# %%
# Init
net.run(tf.global_variables_initializer())

# %%
init = tf.global_variables_initializer()

# %%
# Fit neural net
batch_size = 256
mse_train = []
mse_test = []

# %%
Xencoded.shape
# Out:
# (470486, 1)

# %%
XTencoded.shape
# Out:
# (20,)

# %%
Yencoded.shape
# Out:
# (470486,)

# %%
epochs = 50 #number of iterations or training cycles

saver = tf.train.Saver(max_to_keep=4)
with tf.Session() as sess:
    init.run()
    for e in range(epochs):
        sess.run(opt, feed_dict={X: Xencoded, Y: Yencoded})
        if e % 10 == 0:
            print("-----------------------")
            loss = mse.eval(feed_dict={X: Xencoded, Y: Yencoded})
            print(e, "\tMSE:", loss)
            print("----------save the model")
            saver.save(sess, "model/my-model", global_step=e)   
    y_pred = sess.run(out, feed_dict={X: XTencoded})
# Out:
# -----------------------
# 0 	MSE: 4.06726e+10
# ----------save the model
# -----------------------
# 10 	MSE: 2.37856e+10
# ----------save the model
# -----------------------
# 20 	MSE: 2.23843e+10
# ----------save the model
# -----------------------
# 30 	MSE: 2.21017e+10
# ----------save the model
# -----------------------
# 40 	MSE: 2.21217e+10
# ----------save the model

# %%
sc_test = 'public static CstFloat make(int bits){\n  return new CstFloat(bits);\n}\n'
source_code_test = np.array([sc_test])
encoded_code_test = np.array([vocab_to_int[c] for c in source_code_test], dtype=np.int32)

# %%
encoded_code_test = np.reshape(encoded_code_test, (-1,1))

# %%
def load_model(x_to_predict):
    with tf.Session() as sess:
        saver = tf.train.import_meta_graph('model/my-model-40.meta')
        saver.restore(sess, tf.train.latest_checkpoint("model/"))
        y_pred = sess.run(out, feed_dict={X: x_to_predict})
        print(y_pred)
        return y_pred

# %%
y_pred = load_model()
# Out:
# INFO:tensorflow:Restoring parameters from model/my-model-40
# [[ 249457.8125]]

# %%
y_pred[0][0]
# Out:
# 249457.81

# %%
y_test_int = int(y_pred[0][0])

# %%
y_test_int
# Out:
# 249457

# %%
y_pred_t = np.array([249458])

# %%
y_pred_t
# Out:
# array([249458])

# %%
y_pred_t.shape
# Out:
# (1,)

# %%
y_pred_t = [int_to_vocab[c] for c in y_pred_t]

# %%
y_pred_t
# Out:
# ['Performs a query to return all visible instances in the given range. This is a blocking function and should not be done on the UI thread. This will cause an expansion of recurring events to fill this time range if they are not already expanded and will slow down for larger time ranges with many recurring events.']

# %%
def CommentGenerate(source_code):
    source_code = np.array([source_code])
    encoded_sc = np.array([vocab_to_int[c] for c in source_code], dtype=np.int32)
    y_pred = load_model(encoded_sc)
    encoded_pred = np.array([int(y_pred[0][0])])
    comment_pred = [int_to_vocab[c] for c in encoded_pred]
    return comment_pred

# %%
y_pred = CommentGenerate(source_code)
y_pred

# %%
# CommentGenerate('public static CstFloat make(int bits){\n  return new CstFloat(bits);\n}\n')

# %%
# corpus = []
# w2v_model = Word2Vec(corpus, size=128, window=5, min_count=5, workers=4)
